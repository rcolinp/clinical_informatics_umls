# %%
import pandas as pd
# import numpy as np
import getpass
from neo4j import GraphDatabase

# import matplotlib 
# import matplotlib.pyplot as plt
# plt.style.use('fivethirtyeight')

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option("max_colwidth", 999)
pd.set_option("max_rows", 999)

# %%
# Define connection uri, username & password parameters to establish driver connection (using neo4j official driver)
uri = 'neo4j://0.0.0.0:7687'
user = 'neo4j'
password = getpass.getpass("Please enter password to Neo4j Graph: ") # getpass2
# Out:
# ········

# %% [markdown]
# ##### Create Unique Property Constraints

# %%
# Define driver
driver = GraphDatabase.driver(uri=uri, auth=(user, password))
print(driver)
# Out:
# <neo4j.Neo4jDriver object at 0x12ad5a250>

# %%
# Apply all unique property contraints & indexes to the graph
with driver.session(database="neo4j") as session:
    display(session.run("CREATE CONSTRAINT ON (aui:Atom) ASSERT aui.AtomId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (attribute:Attribute) ASSERT attribute.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (cui:Concept) ASSERT cui.ConceptId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (code:Code) ASSERT code.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (atc:ATC) ASSERT atc.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (drugbank:DRUGBANK) ASSERT drugbank.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ensembl:ENSEMBLGENE_ID) assert ensembl.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (entrez:ENTREZGENE_ID) assert entrez.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (go:GO) ASSERT go.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hgnc:HGNC) ASSERT hgnc.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hpo:HPO) ASSERT hpo.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icdo:ICDO3Code) ASSERT icdo.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd9cm:ICD9CM) ASSERT icd9cm.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10cm:ICD10CM) ASSERT icd10cm.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10pcs:ICD10PCS) ASSERT icd10pcs.ICD10PCS IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ndc:NDC) ASSERT ndc.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (drugclass:IS_DRUG_CLASS) ASSERT drugclass.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (nci:NCI) ASSERT nci.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (msh:MSH) ASSERT msh.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (medrt:`MED-RT`) ASSERT medrt.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (rxnorm:RXNORM) ASSERT rxnorm.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sct:SNOMEDCT_US) ASSERT sct.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.SemanticTypeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.sty IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.stn IS UNIQUE").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.ontology)").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.tty)").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.code)").consume().counters)
# Out:
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}

# %% [markdown]
# # All Labels/Nodes in Graph
#
# - Note: Labels & nodes have been created in a redundant way in-order to handle individual ontologies/vocabularies (i.e. SNOMEDCT_US, NCI HGNC) as labels.
#   - This design implementation allows use of `Code` label (which encompasses all discrete ontologies/vocabularies in the graph - in other words all the other labels except a handful). This enables a broader and more granular approach to querying the graph.
#     - For example, if the goal is to create a SNOMEDCT_US -> ICD10CM crosswalk... It is more intuitive, precise & less time intensive to traverse the graph explicitly based on those labels.
#     - If we flip the scenario, where it is uncertain what crosswalk(s) may exist between any of the vocabularies, then the `Code` label serves as a "catch-all" label for all vocabularies/ontologies within the graph. Thus preventing tedious trial & error to establish what relationships may exist between certain vocabularies.
#
# - **In the next .ipynb (part2) we will explore this in more detail**

# %%
result = {"label": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.labels()"):
        label = row["label"]
        query = f"MATCH (:`{label}`) RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["label"].append(label)
        result["count"].append(count)
nodes_df = pd.DataFrame(data=result)
nodes_df.sort_values(by="count",ascending=False)
# Out:
#              label    count
# 1             Atom  3347400
# 2             Code  1399051
# 0          Concept  1206002
# 15     SNOMEDCT_US   361461
# 17       Attribute   360096
# 11             MSH   347565
# 18             NDC   247545
# 9         ICD10PCS   190673
# 13             NCI   156922
# 14          RXNORM   104437
# 8          ICD10CM    95671
# 21   ENTREZGENE_ID    47070
# 4               GO    44508
# 6             HGNC    41998
# 20  ENSEMBLGENE_ID    38957
# 19       ICDO3Code    25238
# 10          ICD9CM    22406
# 7              HPO    15371
# 5         DRUGBANK     8207
# 3              ATC     6440
# 12          MED-RT     3392
# 22   IS_DRUG_CLASS     1286
# 16    SemanticType      127

# %% [markdown]
# # All Relationships/Edges in the Graph
#
# - Should investigate latter half of list (extremely how counts)
#   - If cannot resolve then possibly best to trim where not providing any value

# %%
result = {"relType": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.relationshipTypes() YIELD relationshipType RETURN relationshipType"):
        relationship_type = row["relationshipType"]
        query = f"MATCH ()-[:`{relationship_type}`]->() RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["relType"].append(relationship_type)
        result["count"].append(count)
rels_df = pd.DataFrame(data=result)
rels_df.sort_values(by="count",ascending=False)
# Out:
#                                                     relType    count
# 2                                              HAS_UMLS_AUI  3347400
# 3                                                   HAS_CUI  2468118
# 0                                                   HAS_STY  1440022
# 1                                                 IS_STY_OF  1440022
# 4                                                 HAS_CHILD  1203510
# 11                                                      ISA   576174
# 20                                              INVERSE_ISA   576174
# 42                                                      PAR   270933
# 39                                                      CHD   270933
# 6                                                       NDC   247545
# 93                                                MAPPED_TO   226861
# 40                                              MAPPED_FROM   226861
# 12                                        CONCEPT_IN_SUBSET   124625
# 275                                 SUBSET_INCLUDES_CONCEPT   124625
# 13                                                       RN   111561
# 9                                                        RB   111561
# 10                                                       RO    79084
# 356                                             CONSISTS_OF    38533
# 369                                             CONSTITUTES    38533
# 25                                             TRADENAME_OF    34724
# 14                                            HAS_TRADENAME    34724
# 358                                          HAS_INGREDIENT    33522
# 351                                           INGREDIENT_OF    33522
# 179                             IS_ABNORMAL_CELL_OF_DISEASE    26596
# 55                                DISEASE_HAS_ABNORMAL_CELL    26596
# 60                                    IS_FINDING_OF_DISEASE    25403
# 52                                      DISEASE_HAS_FINDING    25403
# 5                                                 ICDO3Code    25238
# 357                                           HAS_DOSE_FORM    23683
# 240                                            DOSE_FORM_OF    23683
# 97                                 ASSOCIATED_MORPHOLOGY_OF    21435
# 92                                HAS_ASSOCIATED_MORPHOLOGY    21435
# 121                                              INTERPRETS    20959
# 98                                        IS_INTERPRETED_BY    20959
# 95                                         HAS_FINDING_SITE    17341
# 153                                         FINDING_SITE_OF    17341
# 56                                 DISEASE_EXCLUDES_FINDING    16705
# 75                                IS_NOT_FINDING_OF_DISEASE    16705
# 178                         IS_NOT_ABNORMAL_CELL_OF_DISEASE    13907
# 61                           DISEASE_EXCLUDES_ABNORMAL_CELL    13907
# 41                                                       RQ    12322
# 216                                               METHOD_OF    12158
# 102                                              HAS_METHOD    12158
# 81                       IS_NORMAL_TISSUE_ORIGIN_OF_DISEASE     9950
# 57                         DISEASE_HAS_NORMAL_TISSUE_ORIGIN     9950
# 378                                       HAS_DOSEFORMGROUP     9868
# 377                                        DOSEFORMGROUP_OF     9868
# 94                                 HAS_PATHOLOGICAL_PROCESS     9106
# 439                                 PATHOLOGICAL_PROCESS_OF     9106
# 116                                                  DUE_TO     9014
# 114                                                CAUSE_OF     9014
# 33                                                  PART_OF     8634
# 35                                                 HAS_PART     8634
# 225                                              HAS_PARENT     7410
# 140                                               PARENT_OF     7410
# 224               MAY_BE_CYTOGENETIC_ABNORMALITY_OF_DISEASE     6809
# 73                 DISEASE_MAY_HAVE_CYTOGENETIC_ABNORMALITY     6809
# 120                                              PLAYS_ROLE     6511
# 463                                          ROLE_PLAYED_BY     6511
# 50                                         MANIFESTATION_OF     6400
# 76                                        HAS_MANIFESTATION     6400
# 85                             HAS_ENTIRE_ANATOMY_STRUCTURE     5939
# 391                             ENTIRE_ANATOMY_STRUCTURE_OF     5939
# 54                           DISEASE_HAS_NORMAL_CELL_ORIGIN     5099
# 188                        IS_NORMAL_CELL_ORIGIN_OF_DISEASE     5099
# 59                                MAY_BE_FINDING_OF_DISEASE     4837
# 66                                 DISEASE_MAY_HAVE_FINDING     4837
# 214                        HAS_SUBJECT_RELATIONSHIP_CONTEXT     4820
# 440                         SUBJECT_RELATIONSHIP_CONTEXT_OF     4820
# 284                 MAY_BE_MOLECULAR_ABNORMALITY_OF_DISEASE     4794
# 70                   DISEASE_MAY_HAVE_MOLECULAR_ABNORMALITY     4794
# 87                                       CAUSATIVE_AGENT_OF     4390
# 91                                      HAS_CAUSATIVE_AGENT     4390
# 154                                DIRECT_PROCEDURE_SITE_OF     4192
# 124                               HAS_DIRECT_PROCEDURE_SITE     4192
# 64                     DISEASE_HAS_ASSOCIATED_ANATOMIC_SITE     3962
# 273                          IS_ASSOCIATED_ANATOMIC_SITE_OF     3962
# 90                                     ACTIVE_INGREDIENT_OF     3625
# 206                                   HAS_ACTIVE_INGREDIENT     3625
# 372                                         HAS_INGREDIENTS     3332
# 400                                          INGREDIENTS_OF     3332
# 213                                    HAS_TEMPORAL_CONTEXT     3278
# 465                                     TEMPORAL_CONTEXT_OF     3278
# 30                                                REGULATES     3215
# 34                                             REGULATED_BY     3215
# 22                                             COMPONENT_OF     3186
# 123                                           HAS_COMPONENT     3186
# 151                                      HAS_INTERPRETATION     2941
# 397                                       INTERPRETATION_OF     2941
# 37                                  NEGATIVELY_REGULATED_BY     2785
# 31                                     NEGATIVELY_REGULATES     2785
# 32                                     POSITIVELY_REGULATES     2782
# 38                                  POSITIVELY_REGULATED_BY     2782
# 128                                             USES_DEVICE     2642
# 131                                          DEVICE_USED_BY     2642
# 268                                  HAS_PHYSIOLOGIC_EFFECT     2411
# 253                                   PHYSIOLOGIC_EFFECT_OF     2411
# 44                                           HAS_OCCURRENCE     2166
# 36                                                OCCURS_IN     2166
# 466                                      FINDING_CONTEXT_OF     2149
# 233                                     HAS_FINDING_CONTEXT     2149
# 286                                                      AQ     2113
# 88                                                       QB     2113
# 118                                     DIRECT_SUBSTANCE_OF     2089
# 107                                    HAS_DIRECT_SUBSTANCE     2089
# 311                EO_ANATOMY_IS_ASSOCIATED_WITH_EO_DISEASE     2074
# 309                    EO_DISEASE_HAS_ASSOCIATED_EO_ANATOMY     2074
# 258                     IS_PRIMARY_ANATOMIC_SITE_OF_DISEASE     2055
# 65                        DISEASE_HAS_PRIMARY_ANATOMIC_SITE     2055
# 112                                                FOCUS_OF     1912
# 183                                               HAS_FOCUS     1912
# 19                                               HAS_MEMBER     1837
# 8                                                 MEMBER_OF     1837
# 146                                     HAS_CLINICAL_COURSE     1784
# 388                                      CLINICAL_COURSE_OF     1784
# 130                                        DIRECT_DEVICE_OF     1784
# 157                                       HAS_DIRECT_DEVICE     1784
# 218                                              HAS_INTENT     1652
# 461                                               INTENT_OF     1652
# 49                                               CLASSIFIES     1555
# 58                                            CLASSIFIED_AS     1555
# 43                                        PRIMARY_MAPPED_TO     1437
# 51                                      PRIMARY_MAPPED_FROM     1437
# 231                                         HAS_REALIZATION     1311
# 470                                          REALIZATION_OF     1311
# 137                                 ASSOCIATED_PROCEDURE_OF     1264
# 417                                HAS_ASSOCIATED_PROCEDURE     1264
# 299              IS_MECHANISM_OF_ACTION_OF_CHEMICAL_OR_DRUG     1234
# 18                 CHEMICAL_OR_DRUG_HAS_MECHANISM_OF_ACTION     1234
# 132                            GENE_PRODUCT_ENCODED_BY_GENE     1221
# 134                               GENE_ENCODES_GENE_PRODUCT     1221
# 422                                             SPECIMEN_OF     1204
# 177                                            HAS_SPECIMEN     1204
# 186                                        DISEASE_IS_STAGE     1198
# 340                                     IS_STAGE_OF_DISEASE     1198
# 341  GENE_PRODUCT_SEQUENCE_VARIATION_ENCODED_BY_GENE_MUTANT     1193
# 310     GENE_MUTANT_ENCODES_GENE_PRODUCT_SEQUENCE_VARIATION     1193
# 82                  HAS_PHYSICAL_PART_OF_ANATOMIC_STRUCTURE     1143
# 156                  ANATOMIC_STRUCTURE_IS_PHYSICAL_PART_OF     1143
# 101                BIOLOGICAL_PROCESS_INVOLVES_GENE_PRODUCT     1132
# 122           GENE_PRODUCT_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS     1132
# 189                    IS_NOT_NORMAL_CELL_ORIGIN_OF_DISEASE     1124
# 53                      DISEASE_EXCLUDES_NORMAL_CELL_ORIGIN     1124
# 24                                           HAS_LAB_NUMBER     1087
# 21                                            LAB_NUMBER_OF     1087
# 69                    DISEASE_EXCLUDES_NORMAL_TISSUE_ORIGIN     1074
# 83                   IS_NOT_NORMAL_TISSUE_ORIGIN_OF_DISEASE     1074
# 164                                   ACCESS_DEVICE_USED_BY     1007
# 187                                      USES_ACCESS_DEVICE     1007
# 267                                 HAS_MECHANISM_OF_ACTION     1000
# 262                                  MECHANISM_OF_ACTION_OF     1000
# 352                                  HAS_PRECISE_INGREDIENT      972
# 404                                   PRECISE_INGREDIENT_OF      972
# 297                     IS_MOLECULAR_ABNORMALITY_OF_DISEASE      967
# 167                       DISEASE_HAS_MOLECULAR_ABNORMALITY      967
# 17                  CHEMICAL_OR_DRUG_HAS_PHYSIOLOGIC_EFFECT      949
# 280               IS_PHYSIOLOGIC_EFFECT_OF_CHEMICAL_OR_DRUG      949
# 129                                    DIRECT_MORPHOLOGY_OF      905
# 149                                   HAS_DIRECT_MORPHOLOGY      905
# 138                                         OTHER_MAPPED_TO      828
# 67                                        OTHER_MAPPED_FROM      828
# 165                              INDIRECT_PROCEDURE_SITE_OF      817
# 170                             HAS_INDIRECT_PROCEDURE_SITE      817
# 160                          BASIS_OF_STRENGTH_SUBSTANCE_OF      816
# 374                         HAS_BASIS_OF_STRENGTH_SUBSTANCE      816
# 159                                            OCCURS_AFTER      807
# 106                                           OCCURS_BEFORE      807
# 161                            PRECISE_ACTIVE_INGREDIENT_OF      782
# 375                           HAS_PRECISE_ACTIVE_INGREDIENT      782
# 119                                   ASSOCIATED_FINDING_OF      769
# 234                                  HAS_ASSOCIATED_FINDING      769
# 23                     IS_COMPONENT_OF_CHEMOTHERAPY_REGIMEN      751
# 191                      CHEMOTHERAPY_REGIMEN_HAS_COMPONENT      751
# 168                          DISEASE_MAY_HAVE_ABNORMAL_CELL      738
# 16                                            HAS_SALT_FORM      738
# 15                               HAS_FREE_ACID_OR_BASE_FORM      738
# 185                         MAY_BE_ABNORMAL_CELL_OF_DISEASE      738
# 113                                         ASSOCIATED_WITH      736
# 223             CYTOGENETIC_ABNORMALITY_INVOLVES_CHROMOSOME      684
# 300          CHROMOSOME_INVOLVED_IN_CYTOGENETIC_ABNORMALITY      684
# 77                                      INHERITANCE_TYPE_OF      638
# 80                                     HAS_INHERITANCE_TYPE      638
# 175                                      HAS_PROCEDURE_SITE      594
# 197                                       PROCEDURE_SITE_OF      594
# 423                                  HAS_SPECIMEN_PROCEDURE      582
# 148                                   SPECIMEN_PROCEDURE_OF      582
# 376               HAS_PRESENTATION_STRENGTH_NUMERATOR_VALUE      579
# 415                PRESENTATION_STRENGTH_NUMERATOR_VALUE_OF      579
# 96                                        MAY_BE_TREATED_BY      577
# 271                                               MAY_TREAT      577
# 219                  GENE_INVOLVED_IN_MOLECULAR_ABNORMALITY      575
# 312                     MOLECULAR_ABNORMALITY_INVOLVES_GENE      575
# 410                                  HAS_SPECIMEN_SUBSTANCE      563
# 110                                   SPECIMEN_SUBSTANCE_OF      563
# 133                              GENE_PLAYS_ROLE_IN_PROCESS      555
# 144                                   PROCESS_INVOLVES_GENE      555
# 408                                   HAS_PROCEDURE_CONTEXT      534
# 449                                    PROCEDURE_CONTEXT_OF      534
# 387                                DEVICE_CHARACTERISTIC_OF      497
# 414                               HAS_DEVICE_CHARACTERISTIC      497
# 125                                       SUBSTANCE_USED_BY      474
# 176                                          USES_SUBSTANCE      474
# 7                                                   STY_ISA      464
# 380                                                HAS_FORM      460
# 403                                                 FORM_OF      460
# 248                                   HAS_SURGICAL_APPROACH      440
# 389                                    SURGICAL_APPROACH_OF      440
# 62                   DISEASE_EXCLUDES_MOLECULAR_ABNORMALITY      351
# 296                 IS_NOT_MOLECULAR_ABNORMALITY_OF_DISEASE      351
# 390                                           SCALE_TYPE_OF      347
# 334               IS_NOT_CYTOGENETIC_ABNORMALITY_OF_DISEASE      347
# 63                 DISEASE_EXCLUDES_CYTOGENETIC_ABNORMALITY      347
# 217                                          HAS_SCALE_TYPE      347
# 428                                             PROPERTY_OF      343
# 238                                            HAS_PROPERTY      343
# 338                                VALUE_SET_IS_PAIRED_WITH      328
# 360                                            CONTAINED_IN      328
# 379                                                CONTAINS      328
# 337                                IS_PAIRED_WITH_VALUE_SET      328
# 104                                        HAS_MODIFICATION      324
# 190                                      IS_MODIFICATION_OF      324
# 407                              HAS_COMPOSITIONAL_MATERIAL      323
# 182                               COMPOSITIONAL_MATERIAL_OF      323
# 145                       HAS_PHARMACEUTICAL_TRANSFORMATION      318
# 349                        PHARMACEUTICAL_TRANSFORMATION_OF      318
# 74                     MAY_BE_ASSOCIATED_DISEASE_OF_DISEASE      307
# 71                      DISEASE_MAY_HAVE_ASSOCIATED_DISEASE      307
# 139                     PROCESS_INCLUDES_BIOLOGICAL_PROCESS      279
# 103                   BIOLOGICAL_PROCESS_IS_PART_OF_PROCESS      279
# 373              HAS_CONCENTRATION_STRENGTH_NUMERATOR_VALUE      269
# 416               CONCENTRATION_STRENGTH_NUMERATOR_VALUE_OF      269
# 174           IS_STRUCTURAL_DOMAIN_OR_MOTIF_OF_GENE_PRODUCT      258
# 150             GENE_PRODUCT_HAS_STRUCTURAL_DOMAIN_OR_MOTIF      258
# 255                   IS_CYTOGENETIC_ABNORMALITY_OF_DISEASE      247
# 281                     DISEASE_HAS_CYTOGENETIC_ABNORMALITY      247
# 471                     DOSE_FORM_RELEASE_CHARACTERISTIC_OF      242
# 241                    HAS_DOSE_FORM_RELEASE_CHARACTERISTIC      242
# 473                             DOSE_FORM_TRANSFORMATION_OF      207
# 242                            HAS_DOSE_FORM_TRANSFORMATION      207
# 478                                     FINDING_INFORMER_OF      193
# 246                                    HAS_FINDING_INFORMER      193
# 89                                      STRUCTURAL_CLASS_OF      180
# 269                                    HAS_STRUCTURAL_CLASS      180
# 308                        EO_DISEASE_MAPS_TO_HUMAN_DISEASE      177
# 136                        HUMAN_DISEASE_MAPS_TO_EO_DISEASE      177
# 420                                           HAS_TECHNIQUE      176
# 243                                            TECHNIQUE_OF      176
# 381                            CONTRAINDICATED_WITH_DISEASE      175
# 115                                HAS_CONTRAINDICATED_DRUG      175
# 363                          HAS_PCDC_AML_PERMISSIBLE_VALUE      132
# 109                           PCDC_AML_PERMISSIBLE_VALUE_OF      132
# 108              IS_PCDC_AML_PERMISSIBLE_VALUE_FOR_VARIABLE      132
# 362                          HAS_PCDC_AML_PERMISSABLE_VALUE      132
# 152                 IS_BIOCHEMICAL_FUNCTION_OF_GENE_PRODUCT      123
# 166                   GENE_PRODUCT_HAS_BIOCHEMICAL_FUNCTION      123
# 433                                      HAS_PROCESS_OUTPUT      120
# 117                                       PROCESS_OUTPUT_OF      120
# 364                                      HAS_CTCAE_5_PARENT      119
# 361                                       CTCAE_5_PARENT_OF      119
# 68                                 IS_ASSOCIATED_DISEASE_OF      117
# 289                          DISEASE_HAS_ASSOCIATED_DISEASE      117
# 293                               PROCESS_ALTERED_BY_ALLELE      116
# 325                    ALLELE_PLAYS_ALTERED_ROLE_IN_PROCESS      116
# 331                                  GENE_MAPPED_TO_DISEASE      111
# 304                                  DISEASE_MAPPED_TO_GENE      111
# 226                   PATHOGENESIS_OF_DISEASE_INVOLVES_GENE      108
# 330                GENE_INVOLVED_IN_PATHOGENESIS_OF_DISEASE      108
# 126                                     MAY_BE_PREVENTED_BY      106
# 270                                             MAY_PREVENT      106
# 424                          HAS_SPECIMEN_SOURCE_TOPOGRAPHY       97
# 259                           SPECIMEN_SOURCE_TOPOGRAPHY_OF       97
# 303                      HAS_PHARMACEUTICAL_BASIC_DOSE_FORM       93
# 368                       PHARMACEUTICAL_BASIC_DOSE_FORM_OF       93
# 227                                HAS_GENE_PRODUCT_ELEMENT       91
# 256                      GENE_PRODUCT_IS_ELEMENT_IN_PATHWAY       91
# 173                                     PROCEDURE_DEVICE_OF       88
# 402                                    HAS_PROCEDURE_DEVICE       88
# 72                             DISEASE_MAPPED_TO_CHROMOSOME       86
# 305                            CHROMOSOME_MAPPED_TO_DISEASE       86
# 365                         PHARMACEUTICAL_INTENDED_SITE_OF       82
# 302                        HAS_PHARMACEUTICAL_INTENDED_SITE       82
# 195                GENE_PRODUCT_HAS_CHEMICAL_CLASSIFICATION       79
# 211                                            HAS_LOCATION       79
# 171              IS_CHEMICAL_CLASSIFICATION_OF_GENE_PRODUCT       79
# 203                                    THERAPEUTIC_CLASS_OF       79
# 435                                             LOCATION_OF       79
# 272                                   HAS_THERAPEUTIC_CLASS       79
# 438                                        CHARACTERIZED_BY       78
# 421                                           CHARACTERIZES       78
# 221                    PROCESS_INITIATES_BIOLOGICAL_PROCESS       77
# 99                 BIOLOGICAL_PROCESS_HAS_INITIATOR_PROCESS       77
# 346                          CHROMOSOMAL_LOCATION_OF_ALLELE       70
# 326                          ALLELE_IN_CHROMOSOMAL_LOCATION       70
# 276                                          INVERSE_DURING       66
# 229                                                  DURING       66
# 383                                CONTRAINDICATED_CLASS_OF       61
# 208                               HAS_CONTRAINDICATED_CLASS       61
# 323                     DISEASE_MAY_HAVE_NORMAL_CELL_ORIGIN       60
# 307                    MAY_BE_NORMAL_CELL_ORIGIN_OF_DISEASE       60
# 155                                          ENERGY_USED_BY       59
# 384                                             USES_ENERGY       59
# 111                   IS_ASSOCIATED_ANATOMY_OF_GENE_PRODUCT       57
# 162                     GENE_PRODUCT_HAS_ASSOCIATED_ANATOMY       57
# 192                      ABNORMALITY_ASSOCIATED_WITH_ALLELE       55
# 327                                  ALLELE_HAS_ABNORMALITY       55
# 279                                       KIND_IS_DOMAIN_OF       50
# 100        BIOLOGICAL_PROCESS_HAS_RESULT_BIOLOGICAL_PROCESS       50
# 324                                         ROLE_HAS_DOMAIN       50
# 344                                    GENE_HAS_ABNORMALITY       50
# 105      BIOLOGICAL_PROCESS_RESULTS_FROM_BIOLOGICAL_PROCESS       50
# 345                                  IS_ABNORMALITY_OF_GENE       50
# 292                                      CONCEPTUAL_PART_OF       49
# 169                      HAS_PHARMACEUTICAL_STATE_OF_MATTER       49
# 204                                     HAS_CONCEPTUAL_PART       49
# 367                       PHARMACEUTICAL_STATE_OF_MATTER_OF       49
# 163                                                EXHIBITS       47
# 29                                             EXHIBITED_BY       47
# 298                                          HAS_CTDC_VALUE       46
# 285                                        IS_CTDC_VALUE_OF       46
# 158                                  INDIRECT_MORPHOLOGY_OF       41
# 411                                 HAS_INDIRECT_MORPHOLOGY       41
# 385                  CONTRAINDICATED_MECHANISM_OF_ACTION_OF       41
# 263                 HAS_CONTRAINDICATED_MECHANISM_OF_ACTION       41
# 398                                   TEMPORALLY_RELATED_TO       38
# 382                   CONTRAINDICATED_PHYSIOLOGIC_EFFECT_OF       36
# 254                  HAS_CONTRAINDICATED_PHYSIOLOGIC_EFFECT       36
# 322                                          ROLE_HAS_RANGE       35
# 278                                        KIND_IS_RANGE_OF       35
# 201                  DISEASE_EXCLUDES_PRIMARY_ANATOMIC_SITE       35
# 274                 IS_NOT_PRIMARY_ANATOMIC_SITE_OF_DISEASE       35
# 395                               PART_ANATOMY_STRUCTURE_OF       33
# 260                              HAS_PART_ANATOMY_STRUCTURE       33
# 235                                   RECIPIENT_CATEGORY_OF       32
# 442                                         HAS_TIME_ASPECT       32
# 443                                          TIME_ASPECT_OF       32
# 236                                  HAS_RECIPIENT_CATEGORY       32
# 79                             RELATED_TO_GENETIC_BIOMARKER       29
# 135                            GENETIC_BIOMARKER_RELATED_TO       29
# 386                                     HAS_INDIRECT_DEVICE       29
# 247                                      INDIRECT_DEVICE_OF       29
# 210                                       HAS_REGIONAL_PART       27
# 200                                        REGIONAL_PART_OF       27
# 291                  CHEMICAL_OR_DRUG_AFFECTS_ABNORMAL_CELL       26
# 141                                              ICD_DAGGER       26
# 180              ABNORMAL_CELL_AFFECTED_BY_CHEMICAL_OR_DRUG       26
# 245                   GENE_PRODUCT_HAS_GENE_PRODUCT_VARIANT       24
# 127                                  CONSTITUTIONAL_PART_OF       24
# 359                    GENE_PRODUCT_VARIANT_OF_GENE_PRODUCT       24
# 261                                 HAS_CONSTITUTIONAL_PART       24
# 476                                          DISPOSITION_OF       23
# 239                                         HAS_DISPOSITION       23
# 450                                    HAS_PROCESS_DURATION       22
# 444                                     PROCESS_DURATION_OF       22
# 196                                 PROCEDURE_MORPHOLOGY_OF       21
# 482                                               HAS_UNITS       21
# 448                                                UNITS_OF       21
# 409                                HAS_PROCEDURE_MORPHOLOGY       21
# 306                                               IS_TARGET       20
# 27                                               HAS_TARGET       20
# 212                                               HAS_ALIAS       18
# 199                                                ALIAS_OF       18
# 445                            HAS_SPECIMEN_SOURCE_IDENTITY       16
# 405                             SPECIMEN_SOURCE_IDENTITY_OF       16
# 468                                      HAS_FINDING_METHOD       16
# 406                                       FINDING_METHOD_OF       16
# 451                                HAS_DEVICE_INTENDED_SITE       16
# 434                                 DEVICE_INTENDED_SITE_OF       16
# 366                 PHARMACEUTICAL_ADMINISTRATION_METHOD_OF       15
# 207                           SPECIMEN_SOURCE_MORPHOLOGY_OF       15
# 437                          HAS_SPECIMEN_SOURCE_MORPHOLOGY       15
# 294                HAS_PHARMACEUTICAL_ADMINISTRATION_METHOD       15
# 314                        GENE_PRODUCT_IS_PHYSICAL_PART_OF       14
# 228                               COMPLEX_HAS_PHYSICAL_PART       14
# 250                                            RELATED_PART       12
# 328                                     ALLELE_HAS_ACTIVITY       11
# 321                                         ROLE_HAS_PARENT       11
# 335                                       ROLE_IS_PARENT_OF       11
# 333                                      ACTIVITY_OF_ALLELE       11
# 462                                      BASIC_DOSE_FORM_OF       11
# 472                                     HAS_BASIC_DOSE_FORM       11
# 26             CHEMICAL_OR_DRUG_AFFECTS_CELL_TYPE_OR_TISSUE       10
# 295                         IS_CHROMOSOMAL_LOCATION_OF_GENE       10
# 205                            GENE_IN_CHROMOSOMAL_LOCATION       10
# 425                                              INHERES_IN       10
# 198        CELL_TYPE_OR_TISSUE_AFFECTED_BY_CHEMICAL_OR_DRUG       10
# 427                                  HAS_INHERENT_ATTRIBUTE       10
# 288             DISEASE_HAS_ACCEPTED_TREATMENT_WITH_REGIMEN        9
# 320                    REGIMEN_HAS_ACCEPTED_USE_FOR_DISEASE        9
# 477                      DOSE_FORM_ADMINISTRATION_METHOD_OF        8
# 28        CHEMICAL_OR_DRUG_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS        8
# 301            BIOLOGICAL_PROCESS_INVOLVES_CHEMICAL_OR_DRUG        8
# 458                     HAS_DOSE_FORM_ADMINISTRATION_METHOD        8
# 251                         ANATOMIC_STRUCTURE_HAS_LOCATION        7
# 84                        IS_LOCATION_OF_BIOLOGICAL_PROCESS        7
# 452                                         HAS_DIRECT_SITE        7
# 457                                          DIRECT_SITE_OF        7
# 232              BIOLOGICAL_PROCESS_HAS_ASSOCIATED_LOCATION        7
# 202                       IS_LOCATION_OF_ANATOMIC_STRUCTURE        7
# 209               GENE_PRODUCT_AFFECTED_BY_CHEMICAL_OR_DRUG        6
# 230                   CHEMICAL_OR_DRUG_AFFECTS_GENE_PRODUCT        6
# 313                    BIOMARKER_TYPE_INCLUDES_GENE_PRODUCT        6
# 454                                  HAS_MEASUREMENT_METHOD        6
# 181                          GENE_PRODUCT_IS_BIOMARKER_TYPE        6
# 172                                   MEASUREMENT_METHOD_OF        6
# 426                                     HAS_REVISION_STATUS        5
# 353                                         REFORMULATED_TO        5
# 86                TISSUE_IS_EXPRESSION_SITE_OF_GENE_PRODUCT        5
# 215       BIOLOGICAL_PROCESS_HAS_INITIATOR_CHEMICAL_OR_DRUG        5
# 354                                        REFORMULATION_OF        5
# 412                HAS_PRESENTATION_STRENGTH_NUMERATOR_UNIT        5
# 446                 PRESENTATION_STRENGTH_NUMERATOR_UNIT_OF        5
# 237           CHEMICAL_OR_DRUG_INITIATES_BIOLOGICAL_PROCESS        5
# 339                            GENE_PRODUCT_HAS_ABNORMALITY        5
# 336                        GENE_PRODUCT_EXPRESSED_IN_TISSUE        5
# 332                          IS_ABNORMALITY_OF_GENE_PRODUCT        5
# 290                                        DISEASE_IS_GRADE        5
# 456                                      REVISION_STATUS_OF        5
# 317                                     IS_GRADE_OF_DISEASE        5
# 459                            INGREDIENT_CHARACTERISTIC_OF        4
# 264                                     PHARMACOKINETICS_OF        4
# 78                                              MEASURED_BY        4
# 453                                             HAS_FILLING        4
# 350                                                MEASURES        4
# 484                           HAS_INGREDIENT_CHARACTERISTIC        4
# 318                  IS_PROPERTY_OR_ATTRIBUTE_OF_EO_DISEASE        4
# 222                                              FILLING_OF        4
# 394                                    HAS_PHARMACOKINETICS        4
# 319                    EO_DISEASE_HAS_PROPERTY_OR_ATTRIBUTE        4
# 184                                            ICD_ASTERISK        4
# 194                                     RECEIVES_INPUT_FROM        3
# 143                                       ORGANISM_HAS_GENE        3
# 464                                         PRECONDITION_OF        3
# 45                                   INVERSE_HAPPENS_DURING        3
# 393                                              BOUNDED_BY        3
# 436                                        HAS_PRECONDITION        3
# 474                                           HAS_DEPENDENT        3
# 475                                            DEPENDENT_OF        3
# 193                                         SENDS_OUTPUT_TO        3
# 244                                  GENE_FOUND_IN_ORGANISM        3
# 480                                                  BOUNDS        3
# 48                                           HAPPENS_DURING        3
# 370                  IS_METASTATIC_ANATOMIC_SITE_OF_DISEASE        2
# 249                COMPLETELY_EXCISED_ANATOMY_HAS_PROCEDURE        2
# 371                    DISEASE_HAS_METASTATIC_ANATOMIC_SITE        2
# 460                                             ANTERIOR_TO        2
# 479                              HAS_SURFACE_CHARACTERISTIC        2
# 266                                                 DERIVES        2
# 483                                             RELATIVE_TO        2
# 418                                     INVERSE_RELATIVE_TO        2
# 447                              ROUTE_OF_ADMINISTRATION_OF        2
# 430                                            POSTERIOR_TO        2
# 257                                                 USED_BY        2
# 441                PROCEDURE_HAS_COMPLETELY_EXCISED_ANATOMY        2
# 432                                            DERIVES_FROM        2
# 401                             HAS_ROUTE_OF_ADMINISTRATION        2
# 413                               SURFACE_CHARACTERISTIC_OF        2
# 419                                                    USES        2
# 429                                             INFERIOR_TO        1
# 469                           DEFINITIONAL_MANIFESTATION_OF        1
# 348                                         DATA_ELEMENT_OF        1
# 481                          HAS_DEFINITIONAL_MANIFESTATION        1
# 277                            ASSOCIATED_GENETIC_CONDITION        1
# 355                            GENE_ASSOCIATED_WITH_DISEASE        1
# 347                                        HAS_DATA_ELEMENT        1
# 343                                    QUALIFIER_APPLIES_TO        1
# 342                                         IS_QUALIFIED_BY        1
# 220                                             HOMONYM_FOR        1
# 431                                             SUPERIOR_TO        1
# 467                                            HAS_PRIORITY        1
# 282                                              INDUCED_BY        1
# 392                                                 INDUCES        1
# 283                                              HOMONYM_OF        1
# 252                             DISEASE_HAS_ASSOCIATED_GENE        1
# 46                                              ENDS_DURING        1
# 47                                      INVERSE_ENDS_DURING        1
# 287   CHEMICAL_OR_DRUG_METABOLISM_IS_ASSOCIATED_WITH_ALLELE        1
# 329     ALLELE_PLAYS_ROLE_IN_METABOLISM_OF_CHEMICAL_OR_DRUG        1
# 147       CHEMICAL_OR_DRUG_IS_PRODUCT_OF_BIOLOGICAL_PROCESS        1
# 399                                            MAY_DIAGNOSE        1
# 455                                             PRIORITY_OF        1
# 396                                      SITE_OF_METABOLISM        1
# 316          BIOLOGICAL_PROCESS_HAS_RESULT_CHEMICAL_OR_DRUG        1
# 315                                      ASSOCIATED_DISEASE        1
# 142                                     MAY_BE_DIAGNOSED_BY        1
# 265                                       METABOLIC_SITE_OF        1

# %%
# Close connection
driver.close()

# %% [markdown]
# ##### Establishing a connection using py2neo
# To be covered later

# %%
## py2neo connection (community supported python driver)

# from py2neo import Graph, Relationship, Subgraph, database

# g = Graph(uri=uri, auth=(user, password))

# %%
# result = {"label": [], "count": []}
# for label in g.run("CALL db.labels()").to_series():
#     query = f"MATCH (:`{label}`) RETURN count(*) AS count"
#     count = g.run(query).to_data_frame().iloc[0]['count']
#     result["label"].append(label)
#     result["count"].append(count)
# nodes_df = pd.DataFrame(data=result)
# nodes_df.sort_values(by="count", ascending=False)
