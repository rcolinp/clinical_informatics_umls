# %%
import pandas as pd
import getpass
from neo4j import GraphDatabase


# pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option("max_colwidth", 999)
pd.set_option("max_rows", 999)

# %%
# Define connection uri, username & password parameters to establish driver connection (using neo4j official driver)
uri = 'bolt://localhost:7687'
user = 'neo4j'
password = getpass.getpass("Please enter password to Neo4j Graph: ") # getpass2
# Out:
# Please enter password to Neo4j Graph: ········

# %% [markdown]
# ### Delete Orphan Nodes Prior to Indexing

# %%
# Define driver
driver = GraphDatabase.driver(uri=uri, auth=(user, password))
print(driver)
# driver.close()
# Out:
# <neo4j.BoltDriver object at 0x12cb58520>

# %%
with driver.session(database="neo4j") as session:
    display(session.run("MATCH (attribute:Attribute) WHERE size((attribute)--())=0 DELETE attribute").consume().counters)
# Out:
# {'nodes_deleted': 802}

# %%
with driver.session(database="neo4j") as session:
    display(session.run("MATCH (atom:Atom) WHERE size((atom)--())=0 DELETE atom").consume().counters)
# Out:
# {'nodes_deleted': 429607}

# %% [markdown]
# ### Create Unique Property Constraints & Indexes
#
# Note: Contraints must be applied s/p import of data when utilizing `neo4j-admin import` tool

# %%
# Apply all unique property contraints & indexes to the graph
with driver.session(database="neo4j") as session:
    display(session.run("CREATE CONSTRAINT ON (aui:Atom) ASSERT aui.AtomId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (attribute:Attribute) ASSERT attribute.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (cui:Concept) ASSERT cui.ConceptId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (code:Code) ASSERT code.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (aod:AOD) ASSERT aod.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (atc:ATC) ASSERT atc.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (cvx:CVX) ASSERT cvx.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (drugbank:DRUGBANK) ASSERT drugbank.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ensembl:ENSEMBL) ASSERT ensembl.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (entrez:ENTREZ) ASSERT entrez.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (go:GO) ASSERT go.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hgnc:HGNC) ASSERT hgnc.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hpo:HPO) ASSERT hpo.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icdo:ICDO3Code) ASSERT icdo.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10cm:ICD10CM) ASSERT icd10cm.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10pcs:ICD10PCS) ASSERT icd10pcs.ICD10PCS IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (lnc:LNC) ASSERT lnc.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (mdr:MDR) ASSERT mdr.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (msh:MSH) ASSERT msh.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (medrt:`MED-RT`) ASSERT medrt.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (mmsl:MMSL) ASSERT mmsl.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (mvx:MVX) ASSERT mvx.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ncbi:NCBI) ASSERT ncbi.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (nddf:NDDF) ASSERT nddf.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ndc:NDC) ASSERT ndc.AtuiId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (nci:NCI) ASSERT nci.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (pdq:PDQ) ASSERT pdq.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (rxnorm:RXNORM) ASSERT rxnorm.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sct:SNOMEDCT_US) ASSERT sct.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (src:SRC) ASSERT src.CodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.SemanticTypeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.sty IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.stn IS UNIQUE").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.vocab)").consume().counters)
    display(session.run("CREATE INDEX FOR (atom:Atom) ON (atom.tty)").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.code)").consume().counters)
#     display(session.run("CREATE INDEX FOR (cui:Concept) ON (cui.name)").consume().counters)
# Out:
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}

# %% [markdown]
# # All Labels/Nodes in Graph
#
# - Note: Labels & nodes have been created in a redundant way in-order to handle individual ontologies/vocabularies (i.e. SNOMEDCT_US, NCI HGNC) as labels.
#   - This design implementation allows use of `Code` label (which encompasses all discrete ontologies/vocabularies in the graph - in other words all the other labels except a handful). This enables a broader and more granular approach to querying the graph.
#     - For example, if the goal is to create a SNOMEDCT_US -> ICD10CM crosswalk... It is more intuitive, precise & less time intensive to traverse the graph explicitly based on those labels.
#     - If we flip the scenario, where it is uncertain what crosswalk(s) may exist between any of the vocabularies, then the `Code` label serves as a "catch-all" label for all vocabularies/ontologies within the graph. Thus preventing tedious trial & error to establish what relationships may exist between certain vocabularies.
#
# - **In the next .ipynb (part2) we will explore this in more detail**

# %%
result = {"label": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.labels()"):
        label = row["label"]
        query = f"MATCH (:`{label}`) RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["label"].append(label)
        result["count"].append(count)
nodes_df = pd.DataFrame(data=result)
nodes_df.sort_values(by="count",ascending=False)
# Out:
#            label    count
# 1           Atom  5366894
# 2           Code  3369811
# 0        Concept  3289486
# 19          NCBI  1898664
# 26     Attribute   575716
# 27           NDC   464348
# 11           MSH   327991
# 18   SNOMEDCT_US   298937
# 12           LNC   226838
# 17      ICD10PCS   190608
# 6            NCI    95404
# 24        RXNORM    89326
# 15       ICD10CM    65986
# 29        ENTREZ    47070
# 16            GO    41778
# 14           MDR    41089
# 30       ENSEMBL    38957
# 28     ICDO3Code    25341
# 7           MMSL    22117
# 5           NDDF    19809
# 13           HPO    12417
# 21           MMX    11619
# 8            PDQ     8816
# 3            AOD     8222
# 10      DRUGBANK     4128
# 4            ATC     3151
# 20        MED-RT     2568
# 9            CVX      136
# 22           SRC      128
# 25  SemanticType      127
# 23           MVX       79
# 31          HGNC        0

# %% [markdown]
# # All Relationships/Edges in the Graph
#
# - Should investigate latter half of list (extremely how counts)
#   - If cannot resolve then possibly best to trim where not providing any value

# %%
result = {"relType": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.relationshipTypes() YIELD relationshipType RETURN relationshipType"):
        relationship_type = row["relationshipType"]
        query = f"MATCH ()-[:`{relationship_type}`]->() RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["relType"].append(relationship_type)
        result["count"].append(count)
rels_df = pd.DataFrame(data=result)
rels_df.sort_values(by="count",ascending=False)
# Out:
#                                                     relType    count
# 2                                              HAS_UMLS_AUI  5040497
# 3                                                   HAS_CUI  4982195
# 520                                       ATTRIBUTE_HAS_AUI  3938147
# 1                                                 IS_STY_OF  3567298
# 0                                                   HAS_STY  3567298
# 4                                                 HAS_CHILD  2361769
# 15                                                      PAR  1945392
# 10                                                      CHD  1945392
# 13                                                      ISA   629060
# 19                                              INVERSE_ISA   629060
# 519                                       CUI_HAS_ATTRIBUTE   245389
# 21                                                MAPPED_TO   233237
# 11                                              MAPPED_FROM   233237
# 7                                         HAS_NDC_ATTRIBUTE   214867
# 210                                 SUBSET_INCLUDES_CONCEPT    99457
# 99                                        CONCEPT_IN_SUBSET    99457
# 12                                                       RB    83707
# 9                                                        RN    83707
# 49                                                MEMBER_OF    47763
# 229                                              HAS_MEMBER    47763
# 198                                             CONSISTS_OF    38517
# 201                                             CONSTITUTES    38517
# 39                                              MEASURED_BY    36075
# 238                                                MEASURES    36075
# 104                                          HAS_INGREDIENT    34930
# 16                                            INGREDIENT_OF    34930
# 47                                               HAS_METHOD    34568
# 78                                                METHOD_OF    34568
# 96                                             TRADENAME_OF    33330
# 57                                            HAS_TRADENAME    33330
# 72                                          FINDING_SITE_OF    31930
# 33                                         HAS_FINDING_SITE    31930
# 232                                               HAS_SCALE    31325
# 403                                                SCALE_OF    31325
# 234                                         LOINC_NUMBER_OF    30583
# 513                                        HAS_LOINC_NUMBER    30583
# 67                                             COMPONENT_OF    30517
# 118                                           HAS_COMPONENT    30517
# 79                                        IS_INTERPRETED_BY    30409
# 20                                               INTERPRETS    30409
# 14                                                       RO    28386
# 241                                              HAS_ANSWER    25896
# 129                                               ANSWER_TO    25896
# 158                                            DOSE_FORM_OF    25537
# 199                                           HAS_DOSE_FORM    25537
# 29                                HAS_ASSOCIATED_MORPHOLOGY    22026
# 31                                 ASSOCIATED_MORPHOLOGY_OF    22026
# 178                                     DISEASE_HAS_FINDING    19106
# 287                                   IS_FINDING_OF_DISEASE    19106
# 151                                               SYSTEM_OF    18015
# 236                                              HAS_SYSTEM    18015
# 286                                            MULTIPART_OF    17558
# 239                                           HAS_MULTIPART    17558
# 179                               DISEASE_HAS_ABNORMAL_CELL    17081
# 410                             IS_ABNORMAL_CELL_OF_DISEASE    17081
# 265                                             PROPERTY_OF    15743
# 168                                            HAS_PROPERTY    15743
# 242                                           HAS_CHALLENGE    13524
# 400                                            CHALLENGE_OF    13524
# 180                          DISEASE_EXCLUDES_ABNORMAL_CELL     9943
# 422                         IS_NOT_ABNORMAL_CELL_OF_DISEASE     9943
# 376                                        DOSEFORMGROUP_OF     9868
# 200                                       HAS_DOSEFORMGROUP     9868
# 30                                 HAS_PATHOLOGICAL_PROCESS     9817
# 309                                 PATHOLOGICAL_PROCESS_OF     9817
# 41                                                 CAUSE_OF     9442
# 27                                                   DUE_TO     9442
# 108                                                HAS_PART     9173
# 23                                                  PART_OF     9173
# 288                               IS_NOT_FINDING_OF_DISEASE     8833
# 181                                DISEASE_EXCLUDES_FINDING     8833
# 80                                           HAS_EVALUATION     8806
# 349                                           EVALUATION_OF     8806
# 468                                                CLASS_OF     8255
# 243                                               HAS_CLASS     8255
# 405                                               SUFFIX_OF     7886
# 244                                              HAS_SUFFIX     7886
# 73                                                       RQ     7746
# 6                                       HAS_ICDO3_ATTRIBUTE     7506
# 142                                               PARENT_OF     7365
# 22                                               HAS_PARENT     7365
# 44                                            CLASSIFIED_AS     6578
# 88                                               CLASSIFIES     6578
# 512                                         PARENT_GROUP_OF     6524
# 514                                        HAS_PARENT_GROUP     6524
# 58                             HAS_ENTIRE_ANATOMY_STRUCTURE     5819
# 184                             ENTIRE_ANATOMY_STRUCTURE_OF     5819
# 34                                      HAS_CAUSATIVE_AGENT     5724
# 35                                       CAUSATIVE_AGENT_OF     5724
# 217                DISEASE_MAY_HAVE_CYTOGENETIC_ABNORMALITY     5444
# 344               MAY_BE_CYTOGENETIC_ABNORMALITY_OF_DISEASE     5444
# 66                                HAS_DIRECT_PROCEDURE_SITE     5170
# 76                                 DIRECT_PROCEDURE_SITE_OF     5170
# 77                                        PROCEDURE_SITE_OF     5123
# 56                                       HAS_PROCEDURE_SITE     5123
# 106                        HAS_SUBJECT_RELATIONSHIP_CONTEXT     4895
# 289                         SUBJECT_RELATIONSHIP_CONTEXT_OF     4895
# 408                                     TEMPORAL_CONTEXT_OF     4436
# 105                                    HAS_TEMPORAL_CONTEXT     4436
# 215                  DISEASE_MAY_HAVE_MOLECULAR_ABNORMALITY     4142
# 313                 MAY_BE_MOLECULAR_ABNORMALITY_OF_DISEASE     4142
# 246                                             ANALYZED_BY     4088
# 235                                                ANALYZES     4088
# 304                      IS_NORMAL_TISSUE_ORIGIN_OF_DISEASE     3878
# 193                        DISEASE_HAS_NORMAL_TISSUE_ORIGIN     3878
# 148                               FRAGMENTS_FOR_SYNONYMS_OF     3820
# 237                              HAS_FRAGMENTS_FOR_SYNONYMS     3820
# 252                                         HAS_TIME_ASPECT     3727
# 380                                          TIME_ASPECT_OF     3727
# 226                                         HAS_INGREDIENTS     3331
# 95                                           INGREDIENTS_OF     3331
# 205                               MAY_BE_FINDING_OF_DISEASE     3330
# 214                                DISEASE_MAY_HAVE_FINDING     3330
# 475                                          ROLE_PLAYED_BY     3169
# 156                                              PLAYS_ROLE     3169
# 124                                        DIRECT_DEVICE_OF     3116
# 48                                        HAS_DIRECT_DEVICE     3116
# 306                                               REGULATES     3021
# 299                                            REGULATED_BY     3021
# 36                                       HAS_INTERPRETATION     2957
# 188                                       INTERPRETATION_OF     2957
# 429                          IS_ASSOCIATED_ANATOMIC_SITE_OF     2805
# 191                    DISEASE_HAS_ASSOCIATED_ANATOMIC_SITE     2805
# 283                                          HAS_OCCURRENCE     2661
# 26                                                OCCURS_IN     2661
# 140                                              HAS_INTENT     2648
# 278                                               INTENT_OF     2648
# 355                                    POSITIVELY_REGULATES     2601
# 301                                 POSITIVELY_REGULATED_BY     2601
# 300                                 NEGATIVELY_REGULATED_BY     2597
# 354                                    NEGATIVELY_REGULATES     2597
# 186                                     DIRECT_SUBSTANCE_OF     2550
# 46                                     HAS_DIRECT_SUBSTANCE     2550
# 417                        IS_NORMAL_CELL_ORIGIN_OF_DISEASE     2523
# 190                          DISEASE_HAS_NORMAL_CELL_ORIGIN     2523
# 293                                   PHYSIOLOGIC_EFFECT_OF     2411
# 53                                   HAS_PHYSIOLOGIC_EFFECT     2411
# 84                                              USES_DEVICE     2352
# 123                                          DEVICE_USED_BY     2352
# 128                                     HAS_FINDING_CONTEXT     2292
# 404                                      FINDING_CONTEXT_OF     2292
# 45                                                 FOCUS_OF     2209
# 75                                                HAS_FOCUS     2209
# 17                                                       QB     2113
# 414                    EO_DISEASE_HAS_ASSOCIATED_EO_ANATOMY     2072
# 413                EO_ANATOMY_IS_ASSOCIATED_WITH_EO_DISEASE     2072
# 61                                             OCCURS_AFTER     1923
# 42                                            OCCURS_BEFORE     1923
# 32                                      HAS_CLINICAL_COURSE     1836
# 172                                      CLINICAL_COURSE_OF     1836
# 65                            DEFINITIONAL_MANIFESTATION_OF     1710
# 25                           HAS_DEFINITIONAL_MANIFESTATION     1710
# 192                       DISEASE_HAS_PRIMARY_ANATOMIC_SITE     1484
# 438                     IS_PRIMARY_ANATOMIC_SITE_OF_DISEASE     1484
# 50                                          ASSOCIATED_WITH     1476
# 141                                            HAS_SPECIMEN     1419
# 261                                             SPECIMEN_OF     1419
# 60                                          HAS_REALIZATION     1309
# 480                                          REALIZATION_OF     1309
# 127                                  HAS_ASSOCIATED_FINDING     1263
# 59                                    ASSOCIATED_FINDING_OF     1263
# 166                                HAS_ASSOCIATED_PROCEDURE     1229
# 40                                  ASSOCIATED_PROCEDURE_OF     1229
# 233                                            ARCHETYPE_OF     1225
# 515                                           HAS_ARCHETYPE     1225
# 245                                              DIVISOR_OF     1200
# 240                                             HAS_DIVISOR     1200
# 479  GENE_PRODUCT_SEQUENCE_VARIATION_ENCODED_BY_GENE_MUTANT     1193
# 420     GENE_MUTANT_ENCODES_GENE_PRODUCT_SEQUENCE_VARIATION     1193
# 430                                     IS_STAGE_OF_DISEASE     1130
# 202                                        DISEASE_IS_STAGE     1130
# 169                              INDIRECT_PROCEDURE_SITE_OF     1056
# 117                             HAS_INDIRECT_PROCEDURE_SITE     1056
# 194                                   HAS_ACTIVE_INGREDIENT     1052
# 97                                     ACTIVE_INGREDIENT_OF     1052
# 70                                                  USED_BY     1043
# 82                                                     USES     1043
# 137                                            HAS_APPROACH     1020
# 175                                             APPROACH_OF     1020
# 282                            WOUND_HAS_COMMUNICATION_WITH     1015
# 134                            HAS_COMMUNICATION_WITH_WOUND     1015
# 394                                  MECHANISM_OF_ACTION_OF     1000
# 54                                  HAS_MECHANISM_OF_ACTION     1000
# 100                                  HAS_PRECISE_INGREDIENT      972
# 87                                    PRECISE_INGREDIENT_OF      972
# 292                                    PROCEDURE_CONTEXT_OF      930
# 122                                   HAS_PROCEDURE_CONTEXT      930
# 74                                    HAS_DIRECT_MORPHOLOGY      857
# 64                                     DIRECT_MORPHOLOGY_OF      857
# 112                            GENE_PRODUCT_ENCODED_BY_GENE      827
# 320                               GENE_ENCODES_GENE_PRODUCT      827
# 116                  ANATOMIC_STRUCTURE_IS_PHYSICAL_PART_OF      811
# 114                 HAS_PHYSICAL_PART_OF_ANATOMIC_STRUCTURE      811
# 314                     IS_MOLECULAR_ABNORMALITY_OF_DISEASE      788
# 219                       DISEASE_HAS_MOLECULAR_ABNORMALITY      788
# 223                     DISEASE_EXCLUDES_NORMAL_CELL_ORIGIN      779
# 424                    IS_NOT_NORMAL_CELL_ORIGIN_OF_DISEASE      779
# 353              IS_MECHANISM_OF_ACTION_OF_CHEMICAL_OR_DRUG      753
# 209                CHEMICAL_OR_DRUG_HAS_MECHANISM_OF_ACTION      753
# 327                                    HAS_MODALITY_SUBTYPE      730
# 490                                 IS_MODALITY_SUBTYPE_FOR      730
# 150                BIOLOGICAL_PROCESS_INVOLVES_GENE_PRODUCT      673
# 224           GENE_PRODUCT_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS      673
# 163                                  HAS_MEASURED_COMPONENT      659
# 102                                   MEASURED_COMPONENT_OF      659
# 208                 CHEMICAL_OR_DRUG_HAS_PHYSIOLOGIC_EFFECT      638
# 324               IS_PHYSIOLOGIC_EFFECT_OF_CHEMICAL_OR_DRUG      638
# 146                                   SPECIMEN_SUBSTANCE_OF      610
# 213                                  HAS_SPECIMEN_SUBSTANCE      610
# 51                                    SPECIMEN_PROCEDURE_OF      585
# 262                                  HAS_SPECIMEN_PROCEDURE      585
# 85                                                MAY_TREAT      577
# 18                                        MAY_BE_TREATED_BY      577
# 421                     MOLECULAR_ABNORMALITY_INVOLVES_GENE      572
# 345                  GENE_INVOLVED_IN_MOLECULAR_ABNORMALITY      572
# 412                         MAY_BE_ABNORMAL_CELL_OF_DISEASE      538
# 216                          DISEASE_MAY_HAVE_ABNORMAL_CELL      538
# 171                                DEVICE_CHARACTERISTIC_OF      497
# 159                               HAS_DEVICE_CHARACTERISTIC      497
# 177                                           SCALE_TYPE_OF      493
# 165                                          HAS_SCALE_TYPE      493
# 176                                    SURGICAL_APPROACH_OF      471
# 138                                   HAS_SURGICAL_APPROACH      471
# 8                                             STY_HAS_CHILD      464
# 55                                                  FORM_OF      460
# 38                                                 HAS_FORM      460
# 335                                           HAS_TIMING_OF      435
# 491                                           IS_TIMING_FOR      435
# 316                                            CONTAINED_IN      391
# 317                                                CONTAINS      391
# 71                                               HAS_COURSE      380
# 303                                   PROCESS_INVOLVES_GENE      380
# 318                              GENE_PLAYS_ROLE_IN_PROCESS      380
# 173                                               COURSE_OF      380
# 139                                          USES_SUBSTANCE      336
# 121                                       SUBSTANCE_USED_BY      336
# 472                                VALUE_SET_IS_PAIRED_WITH      328
# 471                                IS_PAIRED_WITH_VALUE_SET      328
# 329                                           HAS_VIEW_TYPE      246
# 290                                        IS_VIEW_TYPE_FOR      246
# 220                  DISEASE_EXCLUDES_MOLECULAR_ABNORMALITY      243
# 312                 IS_NOT_MOLECULAR_ABNORMALITY_OF_DISEASE      243
# 221                DISEASE_EXCLUDES_CYTOGENETIC_ABNORMALITY      240
# 411               IS_NOT_CYTOGENETIC_ABNORMALITY_OF_DISEASE      240
# 398                                         HAS_SUPERSYSTEM      234
# 406                                          SUPERSYSTEM_OF      234
# 120                                      USES_ACCESS_DEVICE      230
# 145                                   ACCESS_DEVICE_USED_BY      230
# 207                    IS_COMPONENT_OF_CHEMOTHERAPY_REGIMEN      221
# 206                      CHEMOTHERAPY_REGIMEN_HAS_COMPONENT      221
# 89                                     HAS_FINDING_INFORMER      202
# 446                                     FINDING_INFORMER_OF      202
# 339                    HAS_DOSE_FORM_RELEASE_CHARACTERISTIC      199
# 496                     DOSE_FORM_RELEASE_CHARACTERISTIC_OF      199
# 143                                    HAS_PROCEDURE_DEVICE      197
# 126                                     PROCEDURE_DEVICE_OF      197
# 62                                    HAS_ACCESS_INSTRUMENT      192
# 153                                    ACCESS_INSTRUMENT_OF      192
# 24                                 HAS_CONTRAINDICATED_DRUG      175
# 92                             CONTRAINDICATED_WITH_DISEASE      175
# 497                             DOSE_FORM_TRANSFORMATION_OF      172
# 340                            HAS_DOSE_FORM_TRANSFORMATION      172
# 441                  IS_NOT_NORMAL_TISSUE_ORIGIN_OF_DISEASE      171
# 211                   DISEASE_EXCLUDES_NORMAL_TISSUE_ORIGIN      171
# 94                                     HAS_STRUCTURAL_CLASS      165
# 37                                      STRUCTURAL_CLASS_OF      165
# 416           IS_STRUCTURAL_DOMAIN_OR_MOTIF_OF_GENE_PRODUCT      162
# 113             GENE_PRODUCT_HAS_STRUCTURAL_DOMAIN_OR_MOTIF      162
# 350                     DISEASE_HAS_CYTOGENETIC_ABNORMALITY      158
# 425                   IS_CYTOGENETIC_ABNORMALITY_OF_DISEASE      158
# 331                                       HAS_IMAGING_FOCUS      140
# 364                                     IS_IMAGING_FOCUS_OF      140
# 463                              HAS_FREE_ACID_OR_BASE_FORM      137
# 305                                           HAS_SALT_FORM      137
# 263                          HAS_SPECIMEN_SOURCE_TOPOGRAPHY      124
# 183                           SPECIMEN_SOURCE_TOPOGRAPHY_OF      124
# 500                                      HAS_CTCAE_5_PARENT      119
# 499                                       CTCAE_5_PARENT_OF      119
# 273                            HAS_SPECIMEN_SOURCE_IDENTITY      117
# 91                              SPECIMEN_SOURCE_IDENTITY_OF      117
# 451                    ALLELE_PLAYS_ALTERED_ROLE_IN_PROCESS      116
# 311                               PROCESS_ALTERED_BY_ALLELE      116
# 83                                      HAS_INSTRUMENTATION      110
# 154                                      INSTRUMENTATION_OF      110
# 469                          HAS_PCDC_AML_PERMISSABLE_VALUE      109
# 426              IS_PCDC_AML_PERMISSIBLE_VALUE_FOR_VARIABLE      109
# 427                           PCDC_AML_PERMISSIBLE_VALUE_OF      109
# 63                                   TEMPORALLY_FOLLOWED_BY      109
# 470                          HAS_PCDC_AML_PERMISSIBLE_VALUE      109
# 131                                      TEMPORALLY_FOLLOWS      109
# 43                                      MAY_BE_PREVENTED_BY      106
# 86                                              MAY_PREVENT      106
# 267                                          EPISODICITY_OF      105
# 130                                         HAS_EPISODICITY      105
# 399                                           ADJUSTMENT_OF      104
# 296                                          HAS_ADJUSTMENT      104
# 161                                        CHARACTERIZED_BY      102
# 250                                           CHARACTERIZES      102
# 393                                  GENE_MAPPED_TO_DISEASE      100
# 382                                  DISEASE_MAPPED_TO_GENE      100
# 196                                       PROCESS_OUTPUT_OF       97
# 255                                      HAS_PROCESS_OUTPUT       97
# 302                   BIOLOGICAL_PROCESS_IS_PART_OF_PROCESS       90
# 149                     PROCESS_INCLUDES_BIOLOGICAL_PROCESS       90
# 68                          ASSOCIATED_ETIOLOGIC_FINDING_OF       89
# 28                         HAS_ASSOCIATED_ETIOLOGIC_FINDING       89
# 249                      GENE_PRODUCT_IS_ELEMENT_IN_PATHWAY       77
# 347                                HAS_GENE_PRODUCT_ELEMENT       77
# 195                                         MANUFACTURED_BY       74
# 445                                            MANUFACTURES       74
# 348                     DISEASE_MAY_HAVE_ASSOCIATED_DISEASE       72
# 325                    MAY_BE_ASSOCIATED_DISEASE_OF_DISEASE       72
# 155                              HAS_COMPOSITIONAL_MATERIAL       71
# 157                               COMPOSITIONAL_MATERIAL_OF       71
# 494                                  IS_AGGREGATION_VIEW_OF       70
# 332                                    HAS_AGGREGATION_VIEW       70
# 452                          ALLELE_IN_CHROMOSOMAL_LOCATION       70
# 434                          CHROMOSOMAL_LOCATION_OF_ALLELE       70
# 328                                HAS_PHARMACEUTICAL_ROUTE       69
# 487                             IS_PHARMACEUTICAL_ROUTE_FOR       69
# 185                                 PROCEDURE_MORPHOLOGY_OF       65
# 225                                          INVERSE_DURING       65
# 125                                HAS_PROCEDURE_MORPHOLOGY       65
# 133                                                  DURING       65
# 310                                                HAS_EXAM       63
# 330                                             IS_EXAM_FOR       63
# 505                         PHARMACEUTICAL_INTENDED_SITE_OF       62
# 373                        HAS_PHARMACEUTICAL_INTENDED_SITE       62
# 152                        HUMAN_DISEASE_MAPS_TO_EO_DISEASE       60
# 415                        EO_DISEASE_MAPS_TO_HUMAN_DISEASE       60
# 277               CONCENTRATION_STRENGTH_NUMERATOR_VALUE_OF       57
# 227              HAS_CONCENTRATION_STRENGTH_NUMERATOR_VALUE       57
# 276                PRESENTATION_STRENGTH_NUMERATOR_VALUE_OF       55
# 228               HAS_PRESENTATION_STRENGTH_NUMERATOR_VALUE       55
# 162                                             USES_ENERGY       54
# 69                                           ENERGY_USED_BY       54
# 447                      ABNORMALITY_ASSOCIATED_WITH_ALLELE       54
# 488                   IS_GIVEN_PHARMACEUTICAL_SUBSTANCE_FOR       54
# 334                      HAS_GIVEN_PHARMACEUTICAL_SUBSTANCE       54
# 453                                  ALLELE_HAS_ABNORMALITY       54
# 375                      HAS_PHARMACEUTICAL_BASIC_DOSE_FORM       53
# 508                       PHARMACEUTICAL_BASIC_DOSE_FORM_OF       53
# 251                                    HAS_PROCESS_DURATION       51
# 379                                     PROCESS_DURATION_OF       51
# 419                                  IS_ABNORMALITY_OF_GENE       50
# 464                                    GENE_HAS_ABNORMALITY       50
# 248                   GENE_PRODUCT_HAS_BIOCHEMICAL_FUNCTION       46
# 321                 IS_BIOCHEMICAL_FUNCTION_OF_GENE_PRODUCT       46
# 365                                       KIND_IS_DOMAIN_OF       43
# 455                                         ROLE_HAS_DOMAIN       43
# 144                                      INDIRECT_DEVICE_OF       42
# 356                    PROCESS_INITIATES_BIOLOGICAL_PROCESS       42
# 119                                     HAS_INDIRECT_DEVICE       42
# 358                BIOLOGICAL_PROCESS_HAS_INITIATOR_PROCESS       42
# 395                 HAS_CONTRAINDICATED_MECHANISM_OF_ACTION       41
# 98                   CONTRAINDICATED_MECHANISM_OF_ACTION_OF       41
# 391                     DISEASE_MAY_HAVE_NORMAL_CELL_ORIGIN       39
# 428                    MAY_BE_NORMAL_CELL_ORIGIN_OF_DISEASE       39
# 333                                  IS_ACTION_GUIDANCE_FOR       39
# 351                                             HAS_VERSION       39
# 352                                              VERSION_OF       39
# 337                                  IS_OBJECT_GUIDANCE_FOR       39
# 326                                     HAS_ACTION_GUIDANCE       39
# 489                                     HAS_OBJECT_GUIDANCE       39
# 268                                      REVISION_STATUS_OF       37
# 160                                     HAS_REVISION_STATUS       37
# 295                  HAS_CONTRAINDICATED_PHYSIOLOGIC_EFFECT       36
# 189                                   TEMPORALLY_RELATED_TO       36
# 101                   CONTRAINDICATED_PHYSIOLOGIC_EFFECT_OF       36
# 103                                        HAS_MODIFICATION       34
# 164                                 HAS_INDIRECT_MORPHOLOGY       34
# 81                                   INDIRECT_MORPHOLOGY_OF       34
# 115                                      IS_MODIFICATION_OF       34
# 372                       HAS_PHARMACEUTICAL_TRANSFORMATION       34
# 486                        PHARMACEUTICAL_TRANSFORMATION_OF       34
# 182                              HAS_PART_ANATOMY_STRUCTURE       31
# 187                               PART_ANATOMY_STRUCTURE_OF       31
# 407                                        TIME_MODIFIER_OF       30
# 474                                        IS_CTDC_VALUE_OF       30
# 297                                       HAS_TIME_MODIFIER       30
# 323                                          HAS_CTDC_VALUE       30
# 392                GENE_INVOLVED_IN_PATHOGENESIS_OF_DISEASE       26
# 449                                          ROLE_HAS_RANGE       26
# 390                   PATHOGENESIS_OF_DISEASE_INVOLVES_GENE       26
# 366                                        KIND_IS_RANGE_OF       26
# 307                  CHEMICAL_OR_DRUG_AFFECTS_ABNORMAL_CELL       25
# 443              ABNORMAL_CELL_AFFECTED_BY_CHEMICAL_OR_DRUG       25
# 458                            RELATED_TO_GENETIC_BIOMARKER       23
# 493                   GENE_PRODUCT_HAS_GENE_PRODUCT_VARIANT       23
# 501                    GENE_PRODUCT_VARIANT_OF_GENE_PRODUCT       23
# 260                                           HAS_TECHNIQUE       23
# 319                            GENETIC_BIOMARKER_RELATED_TO       23
# 258                                            TECHNIQUE_OF       23
# 418        BIOLOGICAL_PROCESS_HAS_RESULT_BIOLOGICAL_PROCESS       22
# 357      BIOLOGICAL_PROCESS_RESULTS_FROM_BIOLOGICAL_PROCESS       22
# 511                                               HAS_UNITS       21
# 111                                       FINDING_METHOD_OF       21
# 294                                      HAS_FINDING_METHOD       21
# 285                                                UNITS_OF       21
# 147                                  POSSIBLY_EQUIVALENT_TO       20
# 383                  DISEASE_EXCLUDES_PRIMARY_ANATOMIC_SITE       17
# 439                 IS_NOT_PRIMARY_ANATOMIC_SITE_OF_DISEASE       17
# 269                                 DEVICE_INTENDED_SITE_OF       16
# 315                                HAS_DEVICE_INTENDED_SITE       16
# 272                            PRECISE_ACTIVE_INGREDIENT_OF       15
# 342                           HAS_PRECISE_ACTIVE_INGREDIENT       15
# 363                GENE_PRODUCT_HAS_CHEMICAL_CLASSIFICATION       14
# 389              IS_CHEMICAL_CLASSIFICATION_OF_GENE_PRODUCT       14
# 341                         HAS_BASIS_OF_STRENGTH_SUBSTANCE       13
# 271                          BASIS_OF_STRENGTH_SUBSTANCE_OF       13
# 197                                         HAS_DISPOSITION       13
# 502                                          DISPOSITION_OF       13
# 93                                 CONTRAINDICATED_CLASS_OF       12
# 52                                HAS_CONTRAINDICATED_CLASS       12
# 457                                       ROLE_IS_PARENT_OF       11
# 388                        GENE_PRODUCT_IS_PHYSICAL_PART_OF       11
# 454                                     ALLELE_HAS_ACTIVITY       11
# 264                                  HAS_INHERENT_ATTRIBUTE       11
# 448                                         ROLE_HAS_PARENT       11
# 253                                              INHERES_IN       11
# 204                                               HAS_ONSET       11
# 174                                                ONSET_OF       11
# 456                                      ACTIVITY_OF_ALLELE       11
# 377                                      BASIC_DOSE_FORM_OF       11
# 385                               COMPLEX_HAS_PHYSICAL_PART       11
# 369                                     HAS_BASIC_DOSE_FORM       11
# 136                                              HAS_EXTENT       10
# 167                                  HAS_MEASUREMENT_METHOD       10
# 170                                               EXTENT_OF       10
# 381                                   MEASUREMENT_METHOD_OF       10
# 5                                      HAS_ENTREZ_ATTRIBUTE        9
# 461                                              HAS_TARGET        9
# 465                                      CONCEPTUAL_PART_OF        9
# 466                                     HAS_CONCEPTUAL_PART        9
# 402                            GENE_IN_CHROMOSOMAL_LOCATION        9
# 257                           SPECIMEN_SOURCE_MORPHOLOGY_OF        9
# 274                          HAS_SPECIMEN_SOURCE_MORPHOLOGY        9
# 401                                               IS_TARGET        9
# 346                         IS_CHROMOSOMAL_LOCATION_OF_GENE        9
# 467                     GENE_PRODUCT_HAS_ASSOCIATED_ANATOMY        8
# 371                     HAS_DOSE_FORM_ADMINISTRATION_METHOD        8
# 503                      DOSE_FORM_ADMINISTRATION_METHOD_OF        8
# 368                                        PROPERTY_TYPE_OF        8
# 254                                       HAS_PROPERTY_TYPE        8
# 308                   IS_ASSOCIATED_ANATOMY_OF_GENE_PRODUCT        8
# 384                                         HAS_DIRECT_SITE        7
# 504                HAS_PHARMACEUTICAL_ADMINISTRATION_METHOD        7
# 275                                          DIRECT_SITE_OF        7
# 506                 PHARMACEUTICAL_ADMINISTRATION_METHOD_OF        7
# 291                                            HAS_LOCATION        6
# 374                      HAS_PHARMACEUTICAL_STATE_OF_MATTER        6
# 270                                             LOCATION_OF        6
# 507                       PHARMACEUTICAL_STATE_OF_MATTER_OF        6
# 440       CHEMICAL_OR_DRUG_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS        5
# 478                            GENE_PRODUCT_HAS_ABNORMALITY        5
# 231                HAS_PRESENTATION_STRENGTH_NUMERATOR_UNIT        5
# 230                                         REFORMULATED_TO        5
# 481                                        REFORMULATION_OF        5
# 431                          IS_ABNORMALITY_OF_GENE_PRODUCT        5
# 222                                        DISEASE_IS_GRADE        5
# 442                                     IS_GRADE_OF_DISEASE        5
# 284                 PRESENTATION_STRENGTH_NUMERATOR_UNIT_OF        5
# 362            BIOLOGICAL_PROCESS_INVOLVES_CHEMICAL_OR_DRUG        5
# 336                                IS_APPROACH_GUIDANCE_FOR        4
# 386                          DISEASE_HAS_ASSOCIATED_DISEASE        4
# 517                           HAS_INGREDIENT_CHARACTERISTIC        4
# 387                                IS_ASSOCIATED_DISEASE_OF        4
# 498                                   HAS_APPROACH_GUIDANCE        4
# 280                            INGREDIENT_CHARACTERISTIC_OF        4
# 476                                          HAPPENS_DURING        3
# 492                                   RECIPIENT_CATEGORY_OF        3
# 483                                            DEPENDENT_OF        3
# 218             DISEASE_HAS_ACCEPTED_TREATMENT_WITH_REGIMEN        3
# 495                                      STATE_OF_MATTER_OF        3
# 482                                           HAS_DEPENDENT        3
# 437           CHEMICAL_OR_DRUG_INITIATES_BIOLOGICAL_PROCESS        3
# 247                                  HAS_RECIPIENT_CATEGORY        3
# 256                                        HAS_PRECONDITION        3
# 359                                  INVERSE_HAPPENS_DURING        3
# 436       BIOLOGICAL_PROCESS_HAS_INITIATOR_CHEMICAL_OR_DRUG        3
# 462                    REGIMEN_HAS_ACCEPTED_USE_FOR_DISEASE        3
# 370                                     HAS_STATE_OF_MATTER        3
# 367                                         PRECONDITION_OF        3
# 396                                     PHARMACOKINETICS_OF        2
# 203                             HAS_ROUTE_OF_ADMINISTRATION        2
# 298                              ROUTE_OF_ADMINISTRATION_OF        2
# 109                                    HAS_PHARMACOKINETICS        2
# 516                                             RELATIVE_TO        2
# 432                  IS_PROPERTY_OR_ATTRIBUTE_OF_EO_DISEASE        2
# 444                    BIOMARKER_TYPE_INCLUDES_GENE_PRODUCT        2
# 433                    EO_DISEASE_HAS_PROPERTY_OR_ATTRIBUTE        2
# 477                          GENE_PRODUCT_IS_BIOMARKER_TYPE        2
# 450                       IS_LOCATION_OF_ANATOMIC_STRUCTURE        2
# 435                         ANATOMIC_STRUCTURE_HAS_LOCATION        2
# 473                        GENE_PRODUCT_EXPRESSED_IN_TISSUE        2
# 259                                     INVERSE_RELATIVE_TO        2
# 423               TISSUE_IS_EXPRESSION_SITE_OF_GENE_PRODUCT        2
# 509                  IS_METASTATIC_ANATOMIC_SITE_OF_DISEASE        1
# 279                                               HAS_STAGE        1
# 518                              HAS_PRODUCT_CHARACTERISTIC        1
# 485                                         DATA_ELEMENT_OF        1
# 409                                            HAS_PRIORITY        1
# 90                                      MAY_BE_DIAGNOSED_BY        1
# 361                                     INVERSE_ENDS_DURING        1
# 107                                                 INDUCES        1
# 459                                         IS_QUALIFIED_BY        1
# 460                                    QUALIFIER_APPLIES_TO        1
# 510                    DISEASE_HAS_METASTATIC_ANATOMIC_SITE        1
# 378                                                MOVED_TO        1
# 281                               PRODUCT_CHARACTERISTIC_OF        1
# 360                                             ENDS_DURING        1
# 266                                             PRIORITY_OF        1
# 212                                                REPLACES        1
# 484                                        HAS_DATA_ELEMENT        1
# 322                                                STAGE_OF        1
# 397                                       METABOLIC_SITE_OF        1
# 132                                              INDUCED_BY        1
# 135                                             REPLACED_BY        1
# 343                                              MOVED_FROM        1
# 338                                            MAY_DIAGNOSE        1
# 110                                      SITE_OF_METABOLISM        1

# %%
# Close connection
driver.close()

# %% [markdown]
# ##### Establishing a connection using py2neo
# To be covered later

# %%
## py2neo connection (community supported python driver)

# from py2neo import Graph, Relationship, Subgraph, database

# g = Graph(uri=uri, auth=(user, password))

# %%
# result = {"label": [], "count": []}
# for label in g.run("CALL db.labels()").to_series():
#     query = f"MATCH (:`{label}`) RETURN count(*) AS count"
#     count = g.run(query).to_data_frame().iloc[0]['count']
#     result["label"].append(label)
#     result["count"].append(count)
# nodes_df = pd.DataFrame(data=result)
# nodes_df.sort_values(by="count", ascending=False)

# %%
# class Neo4jConnection:
    
#     def __init__(self, uri, username, password):
#         self.__uri = uri
#         self.__username = username
#         self.__password = password
#         self.__driver = None
        
#         try:
#             self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__username, self.__password))
#         except Exception as e:
#             print("Failed to create driver", e)
            
#     def close(self):
#         if self.__driver is not None:
#             self.__driver.close()
            
#     def query(self, query, parameters=None, db=None):
#         assert self.__driver is not None, "Driver not initialized."
#         session = None
#         response = None
        
#         try:
#             session = self.__driver.session(database=db) if db is not None else self.__driver.session()
#             response = list(session.run(query, parameters))
#         except Exception as e:
#             print("Query has failed:", e)
#         finally:
#             if session is not None:
#                 session.close()
#         return response
