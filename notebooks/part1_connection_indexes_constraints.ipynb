# %%
import pandas as pd
import getpass
from neo4j import GraphDatabase

pd.set_option("max_colwidth", 999)
pd.set_option("max_rows", 999)

# %%
# Define connection uri, username & password parameters to establish driver connection (using neo4j official driver)
uri = 'neo4j://0.0.0.0:7687'
user = 'neo4j'
password = getpass.getpass("Please enter password to Neo4j Graph: ") # getpass2
# Out:
# Please enter password to Neo4j Graph: ········

# %% [markdown]
# ### Delete Orphan Nodes Prior to Indexing

# %%
# Define driver
driver = GraphDatabase.driver(uri=uri, auth=(user, password))
print(driver)
# driver.close()
# Out:
# <neo4j.Neo4jDriver object at 0x1077612e0>

# %%
# Test connection
with driver.session(database="neo4j") as session:
    display(session.run("match (n:Code) WHERE n.name contains 'Coronavirus' RETURN n.name").data())

# %%
# with driver.session(database="neo4j") as session:
#     display(session.run("MATCH (attribute:Attribute) WHERE size((attribute)--())=0 DELETE attribute").consume().counters)

# %%
# with driver.session(database="neo4j") as session:
#     display(session.run("MATCH (atom:Atom) WHERE size((atom)--())=0 DELETE atom").consume().counters)

# %% [markdown]
# ### Create Unique Property Constraints & Indexes
#
# Note: Contraints must be applied s/p import of data when utilizing `neo4j-admin import` tool

# %%
# Apply all unique property contraints & indexes to the graph
with driver.session(database="neo4j") as session:
    display(session.run("CREATE CONSTRAINT ON (aui:Atom) ASSERT aui.AtomId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (attribute:Attribute) ASSERT attribute.AttributeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (cui:Concept) ASSERT cui.ConceptId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (code:Code) ASSERT code.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (atc:ATC) ASSERT atc.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (go:GO) ASSERT go.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hgnc:HGNC) ASSERT hgnc.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (hpo:HPO) ASSERT hpo.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icdo:ICDO3) ASSERT icdo.AttributeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10cm:ICD10CM) ASSERT icd10cm.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (icd10pcs:ICD10PCS) ASSERT icd10pcs.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (lnc:LNC) ASSERT lnc.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (mdr:MDR) ASSERT mdr.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (msh:MSH) ASSERT msh.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (medrt:`MED-RT`) ASSERT medrt.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ncbi:NCBI) ASSERT ncbi.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (ndc:NDC) ASSERT ndc.AttributeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (nci:NCI) ASSERT nci.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (omim:OMIM) ASSERT omim.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (pdq:PDQ) ASSERT pdq.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (rxnorm:RXNORM) ASSERT rxnorm.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sct:SNOMEDCT_US) ASSERT sct.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (src:SRC) ASSERT src.SourceCodeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.SemanticTypeId IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.sty IS UNIQUE").consume().counters)
    display(session.run("CREATE CONSTRAINT ON (sty:SemanticType) ASSERT sty.stn IS UNIQUE").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.vocab)").consume().counters)
    display(session.run("CREATE INDEX FOR (atom:Atom) ON (atom.tty)").consume().counters)
    display(session.run("CREATE INDEX FOR (code:Code) ON (code.code)").consume().counters)
#     display(session.run("CREATE INDEX FOR (cui:Concept) ON (cui.name)").consume().counters)
# Out:
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'constraints_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}
# {'indexes_added': 1}

# %% [markdown]
# # All Labels/Nodes in Graph
#
# - Note: Labels & nodes have been created in a redundant way in-order to handle individual ontologies/vocabularies (i.e. SNOMEDCT_US, NCI HGNC) as labels.
#   - This design implementation allows use of `Code` label (which encompasses all discrete ontologies/vocabularies in the graph - in other words all the other labels except a handful). This enables a broader and more granular approach to querying the graph.
#     - For example, if the goal is to create a SNOMEDCT_US -> ICD10CM crosswalk... It is more intuitive, precise & less time intensive to traverse the graph explicitly based on those labels.
#     - If we flip the scenario, where it is uncertain what crosswalk(s) may exist between any of the vocabularies, then the `Code` label serves as a "catch-all" label for all vocabularies/ontologies within the graph. Thus preventing tedious trial & error to establish what relationships may exist between certain vocabularies.
#
# - **In the next .ipynb (part2) we will explore this in more detail**

# %%
result = {"label": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.labels()"):
        label = row["label"]
        query = f"MATCH (:`{label}`) RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["label"].append(label)
        result["count"].append(count)
nodes_df = pd.DataFrame(data=result)
nodes_df.sort_values(by="count",ascending=False)
# Out:
#            label    count
# 1           Atom  6311689
# 2           Code  3407786
# 0        Concept  3295170
# 13          NCBI  1898768
# 3            MSH   328010
# 4    SNOMEDCT_US   299049
# 20     Attribute   273003
# 21           NDC   247545
# 5            LNC   231977
# 17      ICD10PCS   190609
# 7            NCI   103129
# 9         RXNORM    89328
# 14          OMIM    74800
# 12       ICD10CM    68230
# 11           MDR    52596
# 6             GO    42054
# 22         ICDO3    25458
# 15           HPO    12822
# 8            PDQ    10266
# 10           ATC     3451
# 16        MED-RT     2569
# 18           SRC      128
# 19  SemanticType      127
# 23          HGNC        0

# %% [markdown]
# # All Relationships/Edges in the Graph
#
# - Should investigate latter half of list (extremely how counts)
#   - If cannot resolve then possibly best to trim where not providing any value

# %%
result = {"relType": [], "count": []}
with driver.session(database="neo4j") as session:
    for row in session.run("CALL db.relationshipTypes() YIELD relationshipType RETURN relationshipType"):
        relationship_type = row["relationshipType"]
        query = f"MATCH ()-[:`{relationship_type}`]->() RETURN count(*) as count"
        count = session.run(query).single()["count"]
        result["relType"].append(relationship_type)
        result["count"].append(count)
rels_df = pd.DataFrame(data=result)
rels_df.sort_values(by="count",ascending=False)
# Out:
#                                                     relType    count
# 2                                             HAS_UMLS_ATOM  5332842
# 3                                                   HAS_CUI  5226222
# 0                                                   HAS_STY  3492268
# 1                                                 IS_STY_OF  3492268
# 4                                                   HAS_AUI  3295170
# 5                                                 HAS_CHILD  2363958
# 10                                                      CHD  1947562
# 15                                                      PAR  1947562
# 529                                       ATTRIBUTE_HAS_AUI  1204869
# 13                                                      ISA   622292
# 19                                              INVERSE_ISA   622292
# 21                                                MAPPED_TO   233233
# 11                                              MAPPED_FROM   233233
# 528                                       CUI_HAS_ATTRIBUTE   121869
# 7                                         HAS_NDC_ATTRIBUTE   114190
# 202                                 SUBSET_INCLUDES_CONCEPT    99457
# 112                                       CONCEPT_IN_SUBSET    99457
# 9                                                        RN    79707
# 12                                                       RB    79707
# 49                                                MEMBER_OF    47763
# 231                                              HAS_MEMBER    47763
# 169                                             CONSTITUTES    38517
# 160                                             CONSISTS_OF    38517
# 39                                              MEASURED_BY    36075
# 224                                                MEASURES    36075
# 78                                                METHOD_OF    34568
# 47                                               HAS_METHOD    34568
# 155                                          HAS_INGREDIENT    33522
# 16                                            INGREDIENT_OF    33522
# 57                                            HAS_TRADENAME    33330
# 108                                            TRADENAME_OF    33330
# 33                                         HAS_FINDING_SITE    31930
# 72                                          FINDING_SITE_OF    31930
# 421                                                SCALE_OF    31325
# 235                                               HAS_SCALE    31325
# 237                                         LOINC_NUMBER_OF    30583
# 521                                        HAS_LOINC_NUMBER    30583
# 67                                             COMPONENT_OF    30517
# 118                                           HAS_COMPONENT    30517
# 79                                        IS_INTERPRETED_BY    30409
# 20                                               INTERPRETS    30409
# 14                                                       RO    26118
# 127                                               ANSWER_TO    25896
# 250                                              HAS_ANSWER    25896
# 161                                           HAS_DOSE_FORM    22835
# 157                                            DOSE_FORM_OF    22835
# 29                                HAS_ASSOCIATED_MORPHOLOGY    22026
# 31                                 ASSOCIATED_MORPHOLOGY_OF    22026
# 301                                   IS_FINDING_OF_DISEASE    19106
# 150                                     DISEASE_HAS_FINDING    19106
# 239                                              HAS_SYSTEM    18015
# 216                                               SYSTEM_OF    18015
# 245                                           HAS_MULTIPART    17558
# 325                                            MULTIPART_OF    17558
# 151                               DISEASE_HAS_ABNORMAL_CELL    17081
# 410                             IS_ABNORMAL_CELL_OF_DISEASE    17081
# 124                                            HAS_PROPERTY    15743
# 279                                             PROPERTY_OF    15743
# 403                                            CHALLENGE_OF    13524
# 251                                           HAS_CHALLENGE    13524
# 154                                       HAS_MANIFESTATION    11695
# 180                                        MANIFESTATION_OF    11695
# 152                          DISEASE_EXCLUDES_ABNORMAL_CELL     9943
# 420                         IS_NOT_ABNORMAL_CELL_OF_DISEASE     9943
# 162                                       HAS_DOSEFORMGROUP     9868
# 376                                        DOSEFORMGROUP_OF     9868
# 327                                 PATHOLOGICAL_PROCESS_OF     9817
# 30                                 HAS_PATHOLOGICAL_PROCESS     9817
# 41                                                 CAUSE_OF     9442
# 27                                                   DUE_TO     9442
# 22                                                  PART_OF     9173
# 158                                                HAS_PART     9173
# 300                               IS_NOT_FINDING_OF_DISEASE     8833
# 153                                DISEASE_EXCLUDES_FINDING     8833
# 80                                           HAS_EVALUATION     8806
# 349                                           EVALUATION_OF     8806
# 476                                                CLASS_OF     8255
# 252                                               HAS_CLASS     8255
# 262                                              HAS_SUFFIX     7886
# 431                                               SUFFIX_OF     7886
# 6                                       HAS_ICDO3_ATTRIBUTE     7706
# 23                                               HAS_PARENT     7365
# 143                                               PARENT_OF     7365
# 73                                                       RQ     6800
# 93                                               CLASSIFIES     6578
# 44                                            CLASSIFIED_AS     6578
# 522                                        HAS_PARENT_GROUP     6524
# 520                                         PARENT_GROUP_OF     6524
# 168                             ENTIRE_ANATOMY_STRUCTURE_OF     5819
# 58                             HAS_ENTIRE_ANATOMY_STRUCTURE     5819
# 34                                      HAS_CAUSATIVE_AGENT     5724
# 35                                       CAUSATIVE_AGENT_OF     5724
# 345               MAY_BE_CYTOGENETIC_ABNORMALITY_OF_DISEASE     5444
# 255                DISEASE_MAY_HAVE_CYTOGENETIC_ABNORMALITY     5444
# 76                                 DIRECT_PROCEDURE_SITE_OF     5170
# 66                                HAS_DIRECT_PROCEDURE_SITE     5170
# 56                                       HAS_PROCEDURE_SITE     5123
# 77                                        PROCEDURE_SITE_OF     5123
# 90                         HAS_SUBJECT_RELATIONSHIP_CONTEXT     4895
# 324                         SUBJECT_RELATIONSHIP_CONTEXT_OF     4895
# 89                                     HAS_TEMPORAL_CONTEXT     4436
# 435                                     TEMPORAL_CONTEXT_OF     4436
# 351                 MAY_BE_MOLECULAR_ABNORMALITY_OF_DISEASE     4142
# 253                  DISEASE_MAY_HAVE_MOLECULAR_ABNORMALITY     4142
# 238                                                ANALYZES     4088
# 273                                             ANALYZED_BY     4088
# 190                        DISEASE_HAS_NORMAL_TISSUE_ORIGIN     3878
# 288                      IS_NORMAL_TISSUE_ORIGIN_OF_DISEASE     3878
# 213                               FRAGMENTS_FOR_SYNONYMS_OF     3820
# 243                              HAS_FRAGMENTS_FOR_SYNONYMS     3820
# 379                                          TIME_ASPECT_OF     3727
# 208                                         HAS_TIME_ASPECT     3727
# 464                                           HAS_PHENOTYPE     3432
# 274                                            PHENOTYPE_OF     3432
# 106                                          INGREDIENTS_OF     3331
# 228                                         HAS_INGREDIENTS     3331
# 223                                DISEASE_MAY_HAVE_FINDING     3330
# 191                               MAY_BE_FINDING_OF_DISEASE     3330
# 483                                          ROLE_PLAYED_BY     3169
# 139                                              PLAYS_ROLE     3169
# 48                                        HAS_DIRECT_DEVICE     3116
# 145                                        DIRECT_DEVICE_OF     3116
# 292                                               REGULATES     3021
# 283                                            REGULATED_BY     3021
# 36                                       HAS_INTERPRETATION     2957
# 177                                       INTERPRETATION_OF     2957
# 442                          IS_ASSOCIATED_ANATOMIC_SITE_OF     2805
# 188                    DISEASE_HAS_ASSOCIATED_ANATOMIC_SITE     2805
# 26                                                OCCURS_IN     2661
# 276                                          HAS_OCCURRENCE     2661
# 268                                               INTENT_OF     2648
# 113                                              HAS_INTENT     2648
# 355                                    POSITIVELY_REGULATES     2601
# 285                                 POSITIVELY_REGULATED_BY     2601
# 284                                 NEGATIVELY_REGULATED_BY     2597
# 354                                    NEGATIVELY_REGULATES     2597
# 46                                     HAS_DIRECT_SUBSTANCE     2550
# 142                                     DIRECT_SUBSTANCE_OF     2550
# 413                        IS_NORMAL_CELL_ORIGIN_OF_DISEASE     2523
# 187                          DISEASE_HAS_NORMAL_CELL_ORIGIN     2523
# 333                                   PHYSIOLOGIC_EFFECT_OF     2411
# 53                                   HAS_PHYSIOLOGIC_EFFECT     2411
# 147                                          DEVICE_USED_BY     2352
# 84                                              USES_DEVICE     2352
# 163                                     HAS_FINDING_CONTEXT     2292
# 436                                      FINDING_CONTEXT_OF     2292
# 45                                                 FOCUS_OF     2209
# 75                                                HAS_FOCUS     2209
# 17                                                       QB     2113
# 88                                                       AQ     2113
# 408                    EO_DISEASE_HAS_ASSOCIATED_EO_ANATOMY     2072
# 409                EO_ANATOMY_IS_ASSOCIATED_WITH_EO_DISEASE     2072
# 61                                             OCCURS_AFTER     1923
# 42                                            OCCURS_BEFORE     1923
# 32                                      HAS_CLINICAL_COURSE     1836
# 132                                      CLINICAL_COURSE_OF     1836
# 65                            DEFINITIONAL_MANIFESTATION_OF     1710
# 25                           HAS_DEFINITIONAL_MANIFESTATION     1710
# 189                       DISEASE_HAS_PRIMARY_ANATOMIC_SITE     1484
# 443                     IS_PRIMARY_ANATOMIC_SITE_OF_DISEASE     1484
# 50                                          ASSOCIATED_WITH     1476
# 240                                             SPECIMEN_OF     1419
# 107                                            HAS_SPECIMEN     1419
# 484                                          REALIZATION_OF     1309
# 60                                          HAS_REALIZATION     1309
# 59                                    ASSOCIATED_FINDING_OF     1263
# 172                                  HAS_ASSOCIATED_FINDING     1263
# 40                                  ASSOCIATED_PROCEDURE_OF     1229
# 196                                HAS_ASSOCIATED_PROCEDURE     1229
# 523                                           HAS_ARCHETYPE     1225
# 236                                            ARCHETYPE_OF     1225
# 272                                              DIVISOR_OF     1200
# 249                                             HAS_DIVISOR     1200
# 488  GENE_PRODUCT_SEQUENCE_VARIATION_ENCODED_BY_GENE_MUTANT     1193
# 417     GENE_MUTANT_ENCODES_GENE_PRODUCT_SEQUENCE_VARIATION     1193
# 194                                        DISEASE_IS_STAGE     1130
# 425                                     IS_STAGE_OF_DISEASE     1130
# 129                              INDIRECT_PROCEDURE_SITE_OF     1056
# 98                              HAS_INDIRECT_PROCEDURE_SITE     1056
# 141                                   HAS_ACTIVE_INGREDIENT     1052
# 101                                    ACTIVE_INGREDIENT_OF     1052
# 82                                                     USES     1043
# 70                                                  USED_BY     1043
# 96                                             HAS_APPROACH     1020
# 135                                             APPROACH_OF     1020
# 275                            WOUND_HAS_COMMUNICATION_WITH     1015
# 206                            HAS_COMMUNICATION_WITH_WOUND     1015
# 397                                  MECHANISM_OF_ACTION_OF     1000
# 54                                  HAS_MECHANISM_OF_ACTION     1000
# 92                                    PRECISE_INGREDIENT_OF      972
# 114                                  HAS_PRECISE_INGREDIENT      972
# 295                                    PROCEDURE_CONTEXT_OF      930
# 111                                   HAS_PROCEDURE_CONTEXT      930
# 74                                    HAS_DIRECT_MORPHOLOGY      857
# 64                                     DIRECT_MORPHOLOGY_OF      857
# 329                               GENE_ENCODES_GENE_PRODUCT      827
# 181                            GENE_PRODUCT_ENCODED_BY_GENE      827
# 166                 HAS_PHYSICAL_PART_OF_ANATOMIC_STRUCTURE      811
# 193                  ANATOMIC_STRUCTURE_IS_PHYSICAL_PART_OF      811
# 352                     IS_MOLECULAR_ABNORMALITY_OF_DISEASE      788
# 257                       DISEASE_HAS_MOLECULAR_ABNORMALITY      788
# 424                    IS_NOT_NORMAL_CELL_ORIGIN_OF_DISEASE      779
# 227                     DISEASE_EXCLUDES_NORMAL_CELL_ORIGIN      779
# 201                CHEMICAL_OR_DRUG_HAS_MECHANISM_OF_ACTION      753
# 386              IS_MECHANISM_OF_ACTION_OF_CHEMICAL_OR_DRUG      753
# 499                                 IS_MODALITY_SUBTYPE_FOR      730
# 313                                    HAS_MODALITY_SUBTYPE      730
# 128           GENE_PRODUCT_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS      673
# 215                BIOLOGICAL_PROCESS_INVOLVES_GENE_PRODUCT      673
# 126                                   MEASURED_COMPONENT_OF      659
# 121                                  HAS_MEASURED_COMPONENT      659
# 308               IS_PHYSIOLOGIC_EFFECT_OF_CHEMICAL_OR_DRUG      638
# 200                 CHEMICAL_OR_DRUG_HAS_PHYSIOLOGIC_EFFECT      638
# 241                                  HAS_SPECIMEN_SUBSTANCE      610
# 167                                   SPECIMEN_SUBSTANCE_OF      610
# 51                                    SPECIMEN_PROCEDURE_OF      585
# 244                                  HAS_SPECIMEN_PROCEDURE      585
# 87                                                MAY_TREAT      577
# 18                                        MAY_BE_TREATED_BY      577
# 423                     MOLECULAR_ABNORMALITY_INVOLVES_GENE      572
# 347                  GENE_INVOLVED_IN_MOLECULAR_ABNORMALITY      572
# 407                         MAY_BE_ABNORMAL_CELL_OF_DISEASE      538
# 254                          DISEASE_MAY_HAVE_ABNORMAL_CELL      538
# 197                               HAS_DEVICE_CHARACTERISTIC      497
# 131                                DEVICE_CHARACTERISTIC_OF      497
# 122                                          HAS_SCALE_TYPE      493
# 137                                           SCALE_TYPE_OF      493
# 97                                    HAS_SURGICAL_APPROACH      471
# 136                                    SURGICAL_APPROACH_OF      471
# 8                                             STY_HAS_CHILD      464
# 38                                                 HAS_FORM      460
# 55                                                  FORM_OF      460
# 500                                           IS_TIMING_FOR      435
# 321                                           HAS_TIMING_OF      435
# 287                                   PROCESS_INVOLVES_GENE      380
# 133                                               COURSE_OF      380
# 328                              GENE_PLAYS_ROLE_IN_PROCESS      380
# 71                                               HAS_COURSE      380
# 125                                       SUBSTANCE_USED_BY      336
# 104                                          USES_SUBSTANCE      336
# 480                                VALUE_SET_IS_PAIRED_WITH      328
# 479                                IS_PAIRED_WITH_VALUE_SET      328
# 311                                                CONTAINS      327
# 309                                            CONTAINED_IN      327
# 315                                           HAS_VIEW_TYPE      246
# 326                                        IS_VIEW_TYPE_FOR      246
# 350                 IS_NOT_MOLECULAR_ABNORMALITY_OF_DISEASE      243
# 258                  DISEASE_EXCLUDES_MOLECULAR_ABNORMALITY      243
# 259                DISEASE_EXCLUDES_CYTOGENETIC_ABNORMALITY      240
# 411               IS_NOT_CYTOGENETIC_ABNORMALITY_OF_DISEASE      240
# 396                                         HAS_SUPERSYSTEM      234
# 432                                          SUPERSYSTEM_OF      234
# 156                                      USES_ACCESS_DEVICE      230
# 212                                   ACCESS_DEVICE_USED_BY      230
# 199                    IS_COMPONENT_OF_CHEMOTHERAPY_REGIMEN      221
# 198                      CHEMOTHERAPY_REGIMEN_HAS_COMPONENT      221
# 433                                     FINDING_INFORMER_OF      202
# 95                                     HAS_FINDING_INFORMER      202
# 506                     DOSE_FORM_RELEASE_CHARACTERISTIC_OF      199
# 340                    HAS_DOSE_FORM_RELEASE_CHARACTERISTIC      199
# 148                                     PROCEDURE_DEVICE_OF      197
# 109                                    HAS_PROCEDURE_DEVICE      197
# 62                                    HAS_ACCESS_INSTRUMENT      192
# 218                                    ACCESS_INSTRUMENT_OF      192
# 24                                 HAS_CONTRAINDICATED_DRUG      175
# 100                            CONTRAINDICATED_WITH_DISEASE      175
# 507                             DOSE_FORM_TRANSFORMATION_OF      172
# 341                            HAS_DOSE_FORM_TRANSFORMATION      172
# 445                  IS_NOT_NORMAL_TISSUE_ORIGIN_OF_DISEASE      171
# 203                   DISEASE_EXCLUDES_NORMAL_TISSUE_ORIGIN      171
# 37                                      STRUCTURAL_CLASS_OF      165
# 105                                    HAS_STRUCTURAL_CLASS      165
# 416           IS_STRUCTURAL_DOMAIN_OR_MOTIF_OF_GENE_PRODUCT      162
# 182             GENE_PRODUCT_HAS_STRUCTURAL_DOMAIN_OR_MOTIF      162
# 381                     DISEASE_HAS_CYTOGENETIC_ABNORMALITY      158
# 412                   IS_CYTOGENETIC_ABNORMALITY_OF_DISEASE      158
# 317                                       HAS_IMAGING_FOCUS      140
# 364                                     IS_IMAGING_FOCUS_OF      140
# 291                                           HAS_SALT_FORM      137
# 455                              HAS_FREE_ACID_OR_BASE_FORM      137
# 242                          HAS_SPECIMEN_SOURCE_TOPOGRAPHY      124
# 165                           SPECIMEN_SOURCE_TOPOGRAPHY_OF      124
# 509                                      HAS_CTCAE_5_PARENT      119
# 508                                       CTCAE_5_PARENT_OF      119
# 263                            HAS_SPECIMEN_SOURCE_IDENTITY      117
# 86                              SPECIMEN_SOURCE_IDENTITY_OF      117
# 306                               PROCESS_ALTERED_BY_ALLELE      116
# 466                    ALLELE_PLAYS_ALTERED_ROLE_IN_PROCESS      116
# 219                                      INSTRUMENTATION_OF      110
# 83                                      HAS_INSTRUMENTATION      110
# 478                          HAS_PCDC_AML_PERMISSIBLE_VALUE      109
# 477                          HAS_PCDC_AML_PERMISSABLE_VALUE      109
# 175                                      TEMPORALLY_FOLLOWS      109
# 63                                   TEMPORALLY_FOLLOWED_BY      109
# 418              IS_PCDC_AML_PERMISSIBLE_VALUE_FOR_VARIABLE      109
# 419                           PCDC_AML_PERMISSIBLE_VALUE_OF      109
# 43                                      MAY_BE_PREVENTED_BY      106
# 91                                              MAY_PREVENT      106
# 247                                          EPISODICITY_OF      105
# 176                                         HAS_EPISODICITY      105
# 402                                           ADJUSTMENT_OF      104
# 312                                          HAS_ADJUSTMENT      104
# 117                                        CHARACTERIZED_BY      102
# 204                                           CHARACTERIZES      102
# 395                                  GENE_MAPPED_TO_DISEASE      100
# 388                                  DISEASE_MAPPED_TO_GENE      100
# 149                                       PROCESS_OUTPUT_OF       97
# 211                                      HAS_PROCESS_OUTPUT       97
# 286                   BIOLOGICAL_PROCESS_IS_PART_OF_PROCESS       90
# 214                     PROCESS_INCLUDES_BIOLOGICAL_PROCESS       90
# 28                         HAS_ASSOCIATED_ETIOLOGIC_FINDING       89
# 68                          ASSOCIATED_ETIOLOGIC_FINDING_OF       89
# 290                      GENE_PRODUCT_IS_ELEMENT_IN_PATHWAY       77
# 332                                HAS_GENE_PRODUCT_ELEMENT       77
# 331                    MAY_BE_ASSOCIATED_DISEASE_OF_DISEASE       72
# 335                     DISEASE_MAY_HAVE_ASSOCIATED_DISEASE       72
# 220                              HAS_COMPOSITIONAL_MATERIAL       71
# 221                               COMPOSITIONAL_MATERIAL_OF       71
# 318                                    HAS_AGGREGATION_VIEW       70
# 462                          ALLELE_IN_CHROMOSOMAL_LOCATION       70
# 503                                  IS_AGGREGATION_VIEW_OF       70
# 429                          CHROMOSOMAL_LOCATION_OF_ALLELE       70
# 314                                HAS_PHARMACEUTICAL_ROUTE       69
# 496                             IS_PHARMACEUTICAL_ROUTE_FOR       69
# 232                                 PROCEDURE_MORPHOLOGY_OF       65
# 184                                                  DURING       65
# 120                                HAS_PROCEDURE_MORPHOLOGY       65
# 183                                          INVERSE_DURING       65
# 305                                                HAS_EXAM       63
# 316                                             IS_EXAM_FOR       63
# 514                         PHARMACEUTICAL_INTENDED_SITE_OF       62
# 373                        HAS_PHARMACEUTICAL_INTENDED_SITE       62
# 217                        HUMAN_DISEASE_MAPS_TO_EO_DISEASE       60
# 415                        EO_DISEASE_MAPS_TO_HUMAN_DISEASE       60
# 229              HAS_CONCENTRATION_STRENGTH_NUMERATOR_VALUE       57
# 267               CONCENTRATION_STRENGTH_NUMERATOR_VALUE_OF       57
# 266                PRESENTATION_STRENGTH_NUMERATOR_VALUE_OF       55
# 230               HAS_PRESENTATION_STRENGTH_NUMERATOR_VALUE       55
# 452                      ABNORMALITY_ASSOCIATED_WITH_ALLELE       54
# 497                   IS_GIVEN_PHARMACEUTICAL_SUBSTANCE_FOR       54
# 119                                             USES_ENERGY       54
# 320                      HAS_GIVEN_PHARMACEUTICAL_SUBSTANCE       54
# 69                                           ENERGY_USED_BY       54
# 463                                  ALLELE_HAS_ABNORMALITY       54
# 375                      HAS_PHARMACEUTICAL_BASIC_DOSE_FORM       53
# 517                       PHARMACEUTICAL_BASIC_DOSE_FORM_OF       53
# 378                                     PROCESS_DURATION_OF       51
# 205                                    HAS_PROCESS_DURATION       51
# 472                                    GENE_HAS_ABNORMALITY       50
# 449                                  IS_ABNORMALITY_OF_GENE       50
# 289                   GENE_PRODUCT_HAS_BIOCHEMICAL_FUNCTION       46
# 353                 IS_BIOCHEMICAL_FUNCTION_OF_GENE_PRODUCT       46
# 450                                         ROLE_HAS_DOMAIN       43
# 365                                       KIND_IS_DOMAIN_OF       43
# 146                                      INDIRECT_DEVICE_OF       42
# 102                                     HAS_INDIRECT_DEVICE       42
# 356                    PROCESS_INITIATES_BIOLOGICAL_PROCESS       42
# 358                BIOLOGICAL_PROCESS_HAS_INITIATOR_PROCESS       42
# 110                  CONTRAINDICATED_MECHANISM_OF_ACTION_OF       41
# 398                 HAS_CONTRAINDICATED_MECHANISM_OF_ACTION       41
# 323                                  IS_OBJECT_GUIDANCE_FOR       39
# 426                    MAY_BE_NORMAL_CELL_ORIGIN_OF_DISEASE       39
# 384                                              VERSION_OF       39
# 393                     DISEASE_MAY_HAVE_NORMAL_CELL_ORIGIN       39
# 319                                  IS_ACTION_GUIDANCE_FOR       39
# 383                                             HAS_VERSION       39
# 334                                     HAS_ACTION_GUIDANCE       39
# 498                                     HAS_OBJECT_GUIDANCE       39
# 248                                      REVISION_STATUS_OF       37
# 116                                     HAS_REVISION_STATUS       37
# 115                   CONTRAINDICATED_PHYSIOLOGIC_EFFECT_OF       36
# 336                  HAS_CONTRAINDICATED_PHYSIOLOGIC_EFFECT       36
# 178                                   TEMPORALLY_RELATED_TO       36
# 144                                        HAS_MODIFICATION       34
# 372                       HAS_PHARMACEUTICAL_TRANSFORMATION       34
# 140                                      IS_MODIFICATION_OF       34
# 489                        PHARMACEUTICAL_TRANSFORMATION_OF       34
# 171                                 HAS_INDIRECT_MORPHOLOGY       34
# 81                                   INDIRECT_MORPHOLOGY_OF       34
# 173                               PART_ANATOMY_STRUCTURE_OF       31
# 164                              HAS_PART_ANATOMY_STRUCTURE       31
# 307                                          HAS_CTDC_VALUE       30
# 434                                        TIME_MODIFIER_OF       30
# 338                                       HAS_TIME_MODIFIER       30
# 482                                        IS_CTDC_VALUE_OF       30
# 471                                     INHERITANCE_TYPE_OF       26
# 394                GENE_INVOLVED_IN_PATHOGENESIS_OF_DISEASE       26
# 470                                    HAS_INHERITANCE_TYPE       26
# 392                   PATHOGENESIS_OF_DISEASE_INVOLVES_GENE       26
# 366                                        KIND_IS_RANGE_OF       26
# 451                                          ROLE_HAS_RANGE       26
# 447              ABNORMAL_CELL_AFFECTED_BY_CHEMICAL_OR_DRUG       25
# 303                  CHEMICAL_OR_DRUG_AFFECTS_ABNORMAL_CELL       25
# 293                                           HAS_TECHNIQUE       23
# 459                            RELATED_TO_GENETIC_BIOMARKER       23
# 277                                            TECHNIQUE_OF       23
# 502                   GENE_PRODUCT_HAS_GENE_PRODUCT_VARIANT       23
# 510                    GENE_PRODUCT_VARIANT_OF_GENE_PRODUCT       23
# 337                            GENETIC_BIOMARKER_RELATED_TO       23
# 414        BIOLOGICAL_PROCESS_HAS_RESULT_BIOLOGICAL_PROCESS       22
# 357      BIOLOGICAL_PROCESS_RESULTS_FROM_BIOLOGICAL_PROCESS       22
# 296                                      HAS_FINDING_METHOD       21
# 94                                        FINDING_METHOD_OF       21
# 524                                               HAS_UNITS       21
# 280                                                UNITS_OF       21
# 185                                  POSSIBLY_EQUIVALENT_TO       20
# 401                  DISEASE_EXCLUDES_PRIMARY_ANATOMIC_SITE       17
# 444                 IS_NOT_PRIMARY_ANATOMIC_SITE_OF_DISEASE       17
# 297                                 DEVICE_INTENDED_SITE_OF       16
# 310                                HAS_DEVICE_INTENDED_SITE       16
# 299                            PRECISE_ACTIVE_INGREDIENT_OF       15
# 343                           HAS_PRECISE_ACTIVE_INGREDIENT       15
# 390              IS_CHEMICAL_CLASSIFICATION_OF_GENE_PRODUCT       14
# 363                GENE_PRODUCT_HAS_CHEMICAL_CLASSIFICATION       14
# 159                                         HAS_DISPOSITION       13
# 511                                          DISPOSITION_OF       13
# 342                         HAS_BASIS_OF_STRENGTH_SUBSTANCE       13
# 298                          BASIS_OF_STRENGTH_SUBSTANCE_OF       13
# 52                                HAS_CONTRAINDICATED_CLASS       12
# 103                                CONTRAINDICATED_CLASS_OF       12
# 467                                     ALLELE_HAS_ACTIVITY       11
# 271                                  HAS_INHERENT_ATTRIBUTE       11
# 454                                       ROLE_IS_PARENT_OF       11
# 458                                         ROLE_HAS_PARENT       11
# 209                                              INHERES_IN       11
# 369                                     HAS_BASIC_DOSE_FORM       11
# 453                                      ACTIVITY_OF_ALLELE       11
# 377                                      BASIC_DOSE_FORM_OF       11
# 186                                               HAS_ONSET       11
# 134                                                ONSET_OF       11
# 391                               COMPLEX_HAS_PHYSICAL_PART       11
# 389                        GENE_PRODUCT_IS_PHYSICAL_PART_OF       11
# 123                                  HAS_MEASUREMENT_METHOD       10
# 382                                   MEASUREMENT_METHOD_OF       10
# 99                                               HAS_EXTENT       10
# 130                                               EXTENT_OF       10
# 473                                      CONCEPTUAL_PART_OF        9
# 474                                     HAS_CONCEPTUAL_PART        9
# 348                         IS_CHROMOSOMAL_LOCATION_OF_GENE        9
# 456                                              HAS_TARGET        9
# 225                           SPECIMEN_SOURCE_MORPHOLOGY_OF        9
# 264                          HAS_SPECIMEN_SOURCE_MORPHOLOGY        9
# 405                            GENE_IN_CHROMOSOMAL_LOCATION        9
# 404                                               IS_TARGET        9
# 512                      DOSE_FORM_ADMINISTRATION_METHOD_OF        8
# 304                   IS_ASSOCIATED_ANATOMY_OF_GENE_PRODUCT        8
# 468                                     HAS_ALLELIC_VARIANT        8
# 368                                        PROPERTY_TYPE_OF        8
# 210                                       HAS_PROPERTY_TYPE        8
# 469                                      ALLELIC_VARIANT_OF        8
# 475                     GENE_PRODUCT_HAS_ASSOCIATED_ANATOMY        8
# 371                     HAS_DOSE_FORM_ADMINISTRATION_METHOD        8
# 515                 PHARMACEUTICAL_ADMINISTRATION_METHOD_OF        7
# 513                HAS_PHARMACEUTICAL_ADMINISTRATION_METHOD        7
# 265                                          DIRECT_SITE_OF        7
# 385                                         HAS_DIRECT_SITE        7
# 374                      HAS_PHARMACEUTICAL_STATE_OF_MATTER        6
# 516                       PHARMACEUTICAL_STATE_OF_MATTER_OF        6
# 261                                             LOCATION_OF        6
# 294                                            HAS_LOCATION        6
# 260                                        DISEASE_IS_GRADE        5
# 446                                     IS_GRADE_OF_DISEASE        5
# 490                                        REFORMULATION_OF        5
# 487                            GENE_PRODUCT_HAS_ABNORMALITY        5
# 278                 PRESENTATION_STRENGTH_NUMERATOR_UNIT_OF        5
# 430       CHEMICAL_OR_DRUG_PLAYS_ROLE_IN_BIOLOGICAL_PROCESS        5
# 233                                         REFORMULATED_TO        5
# 362            BIOLOGICAL_PROCESS_INVOLVES_CHEMICAL_OR_DRUG        5
# 406                          IS_ABNORMALITY_OF_GENE_PRODUCT        5
# 234                HAS_PRESENTATION_STRENGTH_NUMERATOR_UNIT        5
# 526                           HAS_INGREDIENT_CHARACTERISTIC        4
# 504                                   HAS_APPROACH_GUIDANCE        4
# 322                                IS_APPROACH_GUIDANCE_FOR        4
# 269                            INGREDIENT_CHARACTERISTIC_OF        4
# 422                          DISEASE_HAS_ASSOCIATED_DISEASE        4
# 387                                IS_ASSOCIATED_DISEASE_OF        4
# 441           CHEMICAL_OR_DRUG_INITIATES_BIOLOGICAL_PROCESS        3
# 346                                               HAS_ALIAS        3
# 495                                                ALIAS_OF        3
# 494                                            DEPENDENT_OF        3
# 493                                           HAS_DEPENDENT        3
# 192                                  HAS_RECIPIENT_CATEGORY        3
# 501                                   RECIPIENT_CATEGORY_OF        3
# 440       BIOLOGICAL_PROCESS_HAS_INITIATOR_CHEMICAL_OR_DRUG        3
# 485                                          HAPPENS_DURING        3
# 359                                  INVERSE_HAPPENS_DURING        3
# 222                                        HAS_PRECONDITION        3
# 505                                      STATE_OF_MATTER_OF        3
# 457                    REGIMEN_HAS_ACCEPTED_USE_FOR_DISEASE        3
# 370                                     HAS_STATE_OF_MATTER        3
# 256             DISEASE_HAS_ACCEPTED_TREATMENT_WITH_REGIMEN        3
# 367                                         PRECONDITION_OF        3
# 195                             HAS_ROUTE_OF_ADMINISTRATION        2
# 281                                     INVERSE_RELATIVE_TO        2
# 282                              ROUTE_OF_ADMINISTRATION_OF        2
# 174                                    HAS_PHARMACOKINETICS        2
# 525                                             RELATIVE_TO        2
# 448                    BIOMARKER_TYPE_INCLUDES_GENE_PRODUCT        2
# 428                    EO_DISEASE_HAS_PROPERTY_OR_ATTRIBUTE        2
# 399                                     PHARMACOKINETICS_OF        2
# 427                  IS_PROPERTY_OR_ATTRIBUTE_OF_EO_DISEASE        2
# 486                          GENE_PRODUCT_IS_BIOMARKER_TYPE        2
# 438               TISSUE_IS_EXPRESSION_SITE_OF_GENE_PRODUCT        2
# 481                        GENE_PRODUCT_EXPRESSED_IN_TISSUE        2
# 465                       IS_LOCATION_OF_ANATOMIC_STRUCTURE        2
# 439                         ANATOMIC_STRUCTURE_HAS_LOCATION        2
# 518                  IS_METASTATIC_ANATOMIC_SITE_OF_DISEASE        1
# 519                    DISEASE_HAS_METASTATIC_ANATOMIC_SITE        1
# 179                                      SITE_OF_METABOLISM        1
# 170                                                 INDUCES        1
# 138                                              INDUCED_BY        1
# 461                                    QUALIFIER_APPLIES_TO        1
# 460                                         IS_QUALIFIED_BY        1
# 527                              HAS_PRODUCT_CHARACTERISTIC        1
# 85                                      MAY_BE_DIAGNOSED_BY        1
# 437                                            HAS_PRIORITY        1
# 302                                               HAS_STAGE        1
# 207                                             REPLACED_BY        1
# 330                                                STAGE_OF        1
# 226                                                REPLACES        1
# 400                                       METABOLIC_SITE_OF        1
# 246                                             PRIORITY_OF        1
# 380                                                MOVED_TO        1
# 361                                     INVERSE_ENDS_DURING        1
# 270                               PRODUCT_CHARACTERISTIC_OF        1
# 360                                             ENDS_DURING        1
# 344                                              MOVED_FROM        1
# 339                                            MAY_DIAGNOSE        1
# 491                                        HAS_DATA_ELEMENT        1
# 492                                         DATA_ELEMENT_OF        1

# %%
# Close connection
driver.close()

# %% [markdown]
# ##### Establishing a connection using py2neo
# To be covered later

# %%
## py2neo connection (community supported python driver)

# from py2neo import Graph, Relationship, Subgraph, database

# g = Graph(uri=uri, auth=(user, password))

# %%
# result = {"label": [], "count": []}
# for label in g.run("CALL db.labels()").to_series():
#     query = f"MATCH (:`{label}`) RETURN count(*) AS count"
#     count = g.run(query).to_data_frame().iloc[0]['count']
#     result["label"].append(label)
#     result["count"].append(count)
# nodes_df = pd.DataFrame(data=result)
# nodes_df.sort_values(by="count", ascending=False)

# %%
# class Neo4jConnection:
    
#     def __init__(self, uri, username, password):
#         self.__uri = uri
#         self.__username = username
#         self.__password = password
#         self.__driver = None
        
#         try:
#             self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__username, self.__password))
#         except Exception as e:
#             print("Failed to create driver", e)
            
#     def close(self):
#         if self.__driver is not None:
#             self.__driver.close()
            
#     def query(self, query, parameters=None, db=None):
#         assert self.__driver is not None, "Driver not initialized."
#         session = None
#         response = None
        
#         try:
#             session = self.__driver.session(database=db) if db is not None else self.__driver.session()
#             response = list(session.run(query, parameters))
#         except Exception as e:
#             print("Query has failed:", e)
#         finally:
#             if session is not None:
#                 session.close()
#         return response

# %%
# # py2neo connection (community supported python driver)

# from py2neo import Graph

# g = Graph(uri=uri, auth=(user, password))
# test = '''
#         MATCH (a:SNOMEDCT_US)-[:HAS_UMLS_ATOM]->(b:Atom)-[:HAS_CUI]->(c:Concept)
#         <-[:HAS_CUI]-(d:Atom)<-[:HAS_UMLS_ATOM]-(e:HPO) 
#         WHERE EXISTS((c)-[:HAS_STY]->(:SemanticType {sty: 'Neoplastic Process'})) 
#         RETURN DISTINCT a.vocab, a.code, a.name, c.ConceptId, c.name, e.vocab, e.code, e.name
#         '''
# test_df = g.run(test).to_data_frame().drop_duplicates(['c.ConceptId']).replace(np.nan, '')
# test_df.head(10)
